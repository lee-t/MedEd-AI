# %%
# %pip install llama-index
# %pip install llama-index-llms
# %pip install llama-index-embeddings
# %pip install dotenv
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: llama-index in /Users/sam/Library/Python/3.9/lib/python/site-packages (0.10.1)
# Requirement already satisfied: llama-index-agent-openai<0.2.0,>=0.1.0 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from llama-index) (0.1.1)
# Requirement already satisfied: llama-index-core<0.11.0,>=0.10.0 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from llama-index) (0.10.3)
# Requirement already satisfied: llama-index-embeddings-openai<0.2.0,>=0.1.0 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from llama-index) (0.1.1)
# Requirement already satisfied: llama-index-legacy<0.10.0,>=0.9.48 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from llama-index) (0.9.48)
# Requirement already satisfied: llama-index-llms-openai<0.2.0,>=0.1.0 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from llama-index) (0.1.1)
# Requirement already satisfied: llama-index-multi-modal-llms-openai<0.2.0,>=0.1.0 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from llama-index) (0.1.1)
# Requirement already satisfied: llama-index-program-openai<0.2.0,>=0.1.0 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from llama-index) (0.1.1)
# Requirement already satisfied: llama-index-question-gen-openai<0.2.0,>=0.1.0 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from llama-index) (0.1.1)
# Requirement already satisfied: llama-index-readers-file<0.2.0,>=0.1.0 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from llama-index) (0.1.3)
# Requirement already satisfied: PyYAML>=6.0.1 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index) (6.0.1)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.0->llama-index) (2.0.25)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index) (3.9.3)
# Requirement already satisfied: dataclasses-json in /Users/sam/Library/Python/3.9/lib/python/site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index) (0.6.4)
# Requirement already satisfied: deprecated>=1.2.9.3 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index) (2024.2.0)
# Requirement already satisfied: httpx in /Users/sam/Library/Python/3.9/lib/python/site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index) (0.26.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index) (3.2.1)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index) (3.8.1)
# Requirement already satisfied: numpy in /Users/sam/Library/Python/3.9/lib/python/site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index) (1.24.2)
# Requirement already satisfied: openai>=1.1.0 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index) (1.12.0)
# Requirement already satisfied: pandas in /Users/sam/Library/Python/3.9/lib/python/site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index) (2.2.0)
# Requirement already satisfied: pillow>=9.0.0 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index) (10.2.0)
# Requirement already satisfied: requests>=2.31.0 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index) (8.2.3)
# Requirement already satisfied: tiktoken>=0.3.3 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index) (0.6.0)
# Collecting tqdm<5.0.0,>=4.66.1 (from llama-index-core<0.11.0,>=0.10.0->llama-index)
#   Using cached tqdm-4.66.4-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index) (4.9.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from llama-index-core<0.11.0,>=0.10.0->llama-index) (0.8.0)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from llama-index-readers-file<0.2.0,>=0.1.0->llama-index) (4.12.3)
# Requirement already satisfied: bs4<0.0.3,>=0.0.2 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from llama-index-readers-file<0.2.0,>=0.1.0->llama-index) (0.0.2)
# Requirement already satisfied: pymupdf<2.0.0,>=1.23.21 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from llama-index-readers-file<0.2.0,>=0.1.0->llama-index) (1.23.21)
# Requirement already satisfied: pypdf<5.0.0,>=4.0.1 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from llama-index-readers-file<0.2.0,>=0.1.0->llama-index) (4.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.0->llama-index) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.0->llama-index) (22.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.0->llama-index) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.0->llama-index) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.0->llama-index) (1.8.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.0->llama-index) (4.0.2)
# Requirement already satisfied: soupsieve>1.2 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.2.0,>=0.1.0->llama-index) (2.3.2.post1)
# Requirement already satisfied: wrapt<2,>=1.10 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from deprecated>=1.2.9.3->llama-index-core<0.11.0,>=0.10.0->llama-index) (1.15.0)
# Requirement already satisfied: click in /Users/sam/Library/Python/3.9/lib/python/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.0->llama-index) (8.1.7)
# Requirement already satisfied: joblib in /Users/sam/Library/Python/3.9/lib/python/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.0->llama-index) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.0->llama-index) (2023.3.23)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.0->llama-index) (3.6.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.0->llama-index) (1.9.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.0->llama-index) (1.10.11)
# Requirement already satisfied: sniffio in /Users/sam/Library/Python/3.9/lib/python/site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.0->llama-index) (1.3.0)
# Requirement already satisfied: certifi in /Users/sam/Library/Python/3.9/lib/python/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.0->llama-index) (2022.9.24)
# Requirement already satisfied: httpcore==1.* in /Users/sam/Library/Python/3.9/lib/python/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.0->llama-index) (1.0.2)
# Requirement already satisfied: idna in /Users/sam/Library/Python/3.9/lib/python/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.0->llama-index) (3.4)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from httpcore==1.*->httpx->llama-index-core<0.11.0,>=0.10.0->llama-index) (0.14.0)
# Requirement already satisfied: PyMuPDFb==1.23.9 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from pymupdf<2.0.0,>=1.23.21->llama-index-readers-file<0.2.0,>=0.1.0->llama-index) (1.23.9)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.0->llama-index) (2.1.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.0->llama-index) (1.26.13)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.0->llama-index) (3.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.0->llama-index) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from dataclasses-json->llama-index-core<0.11.0,>=0.10.0->llama-index) (3.20.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.0->llama-index) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.0->llama-index) (2022.6)
# Requirement already satisfied: tzdata>=2022.7 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.0->llama-index) (2022.7)
# Requirement already satisfied: packaging>=17.0 in /Users/sam/Library/Python/3.9/lib/python/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.11.0,>=0.10.0->llama-index) (23.2)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->llama-index-core<0.11.0,>=0.10.0->llama-index) (1.15.0)
# Using cached tqdm-4.66.4-py3-none-any.whl (78 kB)
# DEPRECATION: textract 1.6.5 has a non-standard dependency specifier extract-msg<=0.29.*. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of textract or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Installing collected packages: tqdm
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.55.1
#     Uninstalling tqdm-4.55.1:
#       Successfully uninstalled tqdm-4.55.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# promptflow 1.4.1 requires cryptography<42.0.0,>=41.0.3, but you have cryptography 38.0.4 which is incompatible.
# shub 2.15.4 requires tqdm==4.55.1, but you have tqdm 4.66.4 which is incompatible.
# Successfully installed tqdm-4.66.4
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Could not find a version that satisfies the requirement llama-index-llms (from versions: none)
# ERROR: No matching distribution found for llama-index-llms
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Could not find a version that satisfies the requirement llama-index-embeddings (from versions: none)
# ERROR: No matching distribution found for llama-index-embeddings
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting dotenv
#   Using cached dotenv-0.0.5.tar.gz (2.4 kB)
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [64 lines of output]
#       /Users/sam/Library/Python/3.9/lib/python/site-packages/setuptools/installer.py:27: SetuptoolsDeprecationWarning: setuptools.installer is deprecated. Requirements should be satisfied by a PEP 517 installer.
#         warnings.warn(
#         error: subprocess-exited-with-error
#
#         × python setup.py egg_info did not run successfully.
#         │ exit code: 1
#         ╰─> [16 lines of output]
#             Traceback (most recent call last):
#               File "<string>", line 2, in <module>
#               File "<pip-setuptools-caller>", line 14, in <module>
#               File "/private/var/folders/9h/17xh0l9s5fl1s1py0z5h_8gc0000gn/T/pip-wheel-_82716pf/distribute_5380ee0c4d7f43a6a08f473dbd18bc61/setuptools/__init__.py", line 2, in <module>
#                 from setuptools.extension import Extension, Library
#               File "/private/var/folders/9h/17xh0l9s5fl1s1py0z5h_8gc0000gn/T/pip-wheel-_82716pf/distribute_5380ee0c4d7f43a6a08f473dbd18bc61/setuptools/extension.py", line 5, in <module>
#                 from setuptools.dist import _get_unpatched
#               File "/private/var/folders/9h/17xh0l9s5fl1s1py0z5h_8gc0000gn/T/pip-wheel-_82716pf/distribute_5380ee0c4d7f43a6a08f473dbd18bc61/setuptools/dist.py", line 7, in <module>
#                 from setuptools.command.install import install
#               File "/private/var/folders/9h/17xh0l9s5fl1s1py0z5h_8gc0000gn/T/pip-wheel-_82716pf/distribute_5380ee0c4d7f43a6a08f473dbd18bc61/setuptools/command/__init__.py", line 8, in <module>
#                 from setuptools.command import install_scripts
#               File "/private/var/folders/9h/17xh0l9s5fl1s1py0z5h_8gc0000gn/T/pip-wheel-_82716pf/distribute_5380ee0c4d7f43a6a08f473dbd18bc61/setuptools/command/install_scripts.py", line 3, in <module>
#                 from pkg_resources import Distribution, PathMetadata, ensure_directory
#               File "/private/var/folders/9h/17xh0l9s5fl1s1py0z5h_8gc0000gn/T/pip-wheel-_82716pf/distribute_5380ee0c4d7f43a6a08f473dbd18bc61/pkg_resources.py", line 1518, in <module>
#                 register_loader_type(importlib_bootstrap.SourceFileLoader, DefaultProvider)
#             AttributeError: module 'importlib._bootstrap' has no attribute 'SourceFileLoader'
#             [end of output]
#
#         note: This error originates from a subprocess, and is likely not a problem with pip.
#       error: metadata-generation-failed
#
#       × Encountered error while generating package metadata.
#       ╰─> See above for output.
#
#       note: This is an issue with the package mentioned above, not pip.
#       hint: See above for details.
#       Traceback (most recent call last):
#         File "/Users/sam/Library/Python/3.9/lib/python/site-packages/setuptools/installer.py", line 82, in fetch_build_egg
#           subprocess.check_call(cmd)
#         File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/subprocess.py", line 373, in check_call
#           raise CalledProcessError(retcode, cmd)
#       subprocess.CalledProcessError: Command '['/Library/Developer/CommandLineTools/usr/bin/python3', '-m', 'pip', '--disable-pip-version-check', 'wheel', '--no-deps', '-w', '/var/folders/9h/17xh0l9s5fl1s1py0z5h_8gc0000gn/T/tmpm_2m56nb', '--quiet', 'distribute']' returned non-zero exit status 1.
#
#       The above exception was the direct cause of the following exception:
#
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/private/var/folders/9h/17xh0l9s5fl1s1py0z5h_8gc0000gn/T/pip-install-p5a2bda9/dotenv_273b8de7224646fcab897db3b83fa057/setup.py", line 13, in <module>
#           setup(name='dotenv',
#         File "/Users/sam/Library/Python/3.9/lib/python/site-packages/setuptools/__init__.py", line 152, in setup
#           _install_setup_requires(attrs)
#         File "/Users/sam/Library/Python/3.9/lib/python/site-packages/setuptools/__init__.py", line 147, in _install_setup_requires
#           dist.fetch_build_eggs(dist.setup_requires)
#         File "/Users/sam/Library/Python/3.9/lib/python/site-packages/setuptools/dist.py", line 812, in fetch_build_eggs
#           resolved_dists = pkg_resources.working_set.resolve(
#         File "/Users/sam/Library/Python/3.9/lib/python/site-packages/pkg_resources/__init__.py", line 771, in resolve
#           dist = best[req.key] = env.best_match(
#         File "/Users/sam/Library/Python/3.9/lib/python/site-packages/pkg_resources/__init__.py", line 1056, in best_match
#           return self.obtain(req, installer)
#         File "/Users/sam/Library/Python/3.9/lib/python/site-packages/pkg_resources/__init__.py", line 1068, in obtain
#           return installer(requirement)
#         File "/Users/sam/Library/Python/3.9/lib/python/site-packages/setuptools/dist.py", line 883, in fetch_build_egg
#           return fetch_build_egg(self, req)
#         File "/Users/sam/Library/Python/3.9/lib/python/site-packages/setuptools/installer.py", line 84, in fetch_build_egg
#           raise DistutilsError(str(e)) from e
#       distutils.errors.DistutilsError: Command '['/Library/Developer/CommandLineTools/usr/bin/python3', '-m', 'pip', '--disable-pip-version-check', 'wheel', '--no-deps', '-w', '/var/folders/9h/17xh0l9s5fl1s1py0z5h_8gc0000gn/T/tmpm_2m56nb', '--quiet', 'distribute']' returned non-zero exit status 1.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Load Credentials

# %%
from __future__ import print_function
import logging
import sys
import os
from dotenv import load_dotenv
from llama_index.core import ( Settings, VectorStoreIndex, SimpleDirectoryReader, ServiceContext, StorageContext, load_index_from_storage)
from llama_index.core.callbacks import CallbackManager
from llama_index.core.node_parser import SentenceWindowNodeParser
from llama_index.core.postprocessor import MetadataReplacementPostProcessor
from llama_index.embeddings.azure_openai import AzureOpenAIEmbedding
from llama_index.llms.azure_openai import AzureOpenAI
from langchain.text_splitter import RecursiveCharacterTextSplitter
from llama_index.core.node_parser import LangchainNodeParser

logging.getLogger().setLevel(logging.WARNING)

load_dotenv('../Credentials/.env')

user_path = "Users/sam/dev/spaghetti_dev/"

endpoint = os.getenv("AZURE_OPENAI_ENDPOINT")
credential = os.getenv("AZURE_OPENAI_API_KEY")
azure_openai_api_version = "2024-04-01-preview"
azure_openai_embedding_deployment = "text-embedding-ada-002"
embedding_model_name = "text-embedding-ada-002"
llm_model_name = "gpt-35-turbo-16k"
api_type = "azure"

# %% [markdown]
# ## Load Documents

# %%
reader = SimpleDirectoryReader("".join([user_path,"MedEd-AI/Data/studentguides/"]), recursive=True, filename_as_id=True, required_exts=[".pdf", ".docx", ".xlsx", ".pptx"])

documents = []
for docs in reader.iter_data():
    documents.extend(docs)

# %%
documents[0].metadata
# Out:
# {'page_label': '1',
#  'file_name': '1-s2.0-S1538544221000821-main.pdf',
#  'file_path': '/Users/sam/dev/spaghetti_dev/MedEd-AI/Code/../Data/course113113/downloads/1-s2.0-S1538544221000821-main.pdf',
#  'file_type': 'application/pdf',
#  'file_size': 719173,
#  'creation_date': '2024-04-16',
#  'last_modified_date': '2024-04-16'}

# %% [markdown]
# ## Node Parsing

# %%
parser = LangchainNodeParser(RecursiveCharacterTextSplitter(
    # Set a really small chunk size, just to show.
    chunk_size=100,
    chunk_overlap=20,
    length_function=len,
    is_separator_regex=False,
))

nodes = parser.get_nodes_from_documents(documents)

# %% [markdown]
# ## Create Index

# %%
llm = AzureOpenAI(
            model = llm_model_name,
            deployment_name = llm_model_name,
            api_key = credential,
            azure_endpoint = endpoint,
            api_version = azure_openai_api_version,
            api_type = api_type
        )

embed_model = AzureOpenAIEmbedding(
            model = embedding_model_name,
            deployment_name = embedding_model_name,
            api_key = credential,
            azure_endpoint = endpoint,
            api_version = azure_openai_api_version,
            api_type = api_type,
            embed_batch_size=50
        )

Settings.llm = llm
Settings.embed_model = embed_model

callback_manager = CallbackManager()

index = VectorStoreIndex(nodes)

print("Index created")
# Out:
# Index created

# %% [markdown]
# ## Save to Persistent Storage
#
# In case you want to load your index later, saving you from having to re-parse your documents every time

# %%
index.storage_context.persist(persist_dir="../Data/course113113_index")

# %% [markdown]
# ## Create Query Engine, Ask a Question

# %%
query_engine = index.as_query_engine(similarity_top_k=5)

query = (
    'Please create a 5 question review quiz on the pharmacology of antithrombotics . Do not ask questions about text from a photo/graph. Do not ask any questions about textbook sections. Every question should have only one correct answer. Every question should have 4 potential answers. Every answer option should have a detailed explanation. Format the output like this:{"info":{"title": "", "description": "", "questions": [ { "question": "","type": "RADIO","options": [{"option":"","explanation":""}], "correct_answer": ""}]}}'
)

query_response = query_engine.query(
    query
)

print(query_response)
# Out:
# {"info":{"title": "Pharmacology of Antithrombotics Quiz", "description": "This quiz will test your knowledge on the pharmacology of antithrombotics. Each question has one correct answer and four potential answer options. Read each question carefully and select the best answer.", "questions": [
# {
#   "question": "What is the main purpose of antithrombotics?",
#   "type": "RADIO",
#   "options": [
#     {"option": "To promote thrombus formation", "explanation": "Incorrect. Antithrombotics are agents that prevent and/or reverse thrombus formation."},
#     {"option": "To treat hypertension", "explanation": "Incorrect. Antithrombotics are not primarily used to treat hypertension."},
#     {"option": "To prevent and/or reverse thrombus formation", "explanation": "Correct. Antithrombotics are agents that prevent and/or reverse thrombus formation."},
#     {"option": "To promote blood clotting", "explanation": "Incorrect. Antithrombotics do not promote blood clotting."}
#   ],
#   "correct_answer": "To prevent and/or reverse thrombus formation"
# },
# {
#   "question": "What are antithrombotics primarily used for?",
#   "type": "RADIO",
#   "options": [
#     {"option": "Treating diabetes", "explanation": "Incorrect. Antithrombotics are not primarily used to treat diabetes."},
#     {"option": "Preventing and/or treating infections", "explanation": "Incorrect. Antithrombotics are not primarily used to prevent or treat infections."},
#     {"option": "Preventing and/or treating thrombus formation", "explanation": "Correct. Antithrombotics are primarily used to prevent and/or treat thrombus formation."},
#     {"option": "Managing pain", "explanation": "Incorrect. Antithrombotics are not primarily used to manage pain."}
#   ],
#   "correct_answer": "Preventing and/or treating thrombus formation"
# },
# {
#   "question": "What are the categories of antithrombotics based on?",
#   "type": "RADIO",
#   "options": [
#     {"option": "Color", "explanation": "Incorrect. The categories of antithrombotics are not based on color."},
#     {"option": "Mechanism of action and therapeutic target", "explanation": "Correct. Antithrombotics are categorized based on their mechanism of action and therapeutic target."},
#     {"option": "Price", "explanation": "Incorrect. The categories of antithrombotics are not based on price."},
#     {"option": "Brand name", "explanation": "Incorrect. The categories of antithrombotics are not based on brand name."}
#   ],
#   "correct_answer": "Mechanism of action and therapeutic target"
# },
# {
#   "question": "What is the purpose of antithrombotics in hemostasis?",
#   "type": "RADIO",
#   "options": [
#     {"option": "To promote clot formation", "explanation": "Incorrect. Antithrombotics do not promote clot formation in hemostasis."},
#     {"option": "To prevent clot formation", "explanation": "Correct. Antithrombotics prevent clot formation in hemostasis."},
#     {"option": "To dissolve existing clots", "explanation": "Incorrect. Antithrombotics do not dissolve existing clots in hemostasis."},
#     {"option": "To increase platelet count", "explanation": "Incorrect. Antithrombotics do not increase platelet count in hemostasis."}
#   ],
#   "correct_answer": "To prevent clot formation"
# },
# {
#   "question": "What is the role of antithrombotics in treating thrombus formation?",
#   "type": "RADIO",
#   "options": [
#     {"option": "To promote thrombus formation", "explanation": "Incorrect. Antithrombotics do not promote thrombus formation."},
#     {"option": "To prevent and/or reverse thrombus formation", "explanation": "Correct. Antithrombotics are used to prevent and/or reverse thrombus formation."},
#     {"option": "To increase blood pressure", "explanation": "Incorrect. Antithrombotics do not increase blood pressure."},
#     {"option": "To reduce blood viscosity", "explanation": "Incorrect. Antithrombotics do not reduce blood viscosity."}
#   ],
#   "correct_answer": "To prevent and/or reverse thrombus formation"
# }
# ]}}
