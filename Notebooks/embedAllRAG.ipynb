# %% [markdown]
# ### Install requirements

# %%
# %pip install -r requirements.txt

# %% [markdown]
# ### Load Libraries, Set Global Variables and Settings

# %%
from __future__ import print_function
import logging
import sys
import os
import glob
from dotenv import load_dotenv
import logging
import sys
import duckdb
from llama_index.embeddings.azure_openai import AzureOpenAIEmbedding
from llama_index.llms.azure_openai import AzureOpenAI
from llama_index.core import ( Settings, VectorStoreIndex, SimpleDirectoryReader)
from llama_index.core.callbacks import CallbackManager, LlamaDebugHandler
from llama_index.vector_stores.chroma import ChromaVectorStore
from llama_index.core import (StorageContext, ServiceContext)
from llama_index.core.node_parser import MarkdownNodeParser
import chromadb
import datetime
import numpy as np
from llama_index.core.vector_stores import MetadataFilter, MetadataFilters, ExactMatchFilter
from sqlalchemy import *
from llama_index.core.node_parser import SentenceSplitter
from llama_index.core.tools import QueryEngineTool
from llama_index.core.tools import ToolMetadata
from llama_index.core.query_engine import SubQuestionQueryEngine
from llama_index.core import SQLDatabase, Document
from llama_index.core.query_engine import NLSQLTableQueryEngine
from llama_index.core.indices.struct_store import SQLTableRetrieverQueryEngine
from llama_index.core.retrievers import VectorIndexAutoRetriever
from llama_index.core.query_engine import RetrieverQueryEngine
from llama_index.core.node_parser import SentenceWindowNodeParser
from llama_index.core.query_engine import SQLJoinQueryEngine
from llama_index.vector_stores.duckdb import DuckDBVectorStore
from llama_index.core.retrievers import VectorIndexAutoRetriever
from llama_index.core.vector_stores import MetadataInfo, VectorStoreInfo
from langchain.text_splitter import RecursiveCharacterTextSplitter
from llama_index.core.node_parser import LangchainNodeParser
from sqlalchemy import (create_engine,MetaData,Table,Column,String,Integer,select,column,)
from sqlalchemy.dialects.postgresql import (INTEGER, FLOAT, BIGINT, VARCHAR, DOUBLE_PRECISION)
from llama_index.core.query_engine import NLSQLTableQueryEngine
from llama_index.core.indices.struct_store import SQLTableRetrieverQueryEngine
from llama_index.core.objects import (SQLTableNodeMapping,ObjectIndex,SQLTableSchema,)
from llama_index.core import VectorStoreIndex
from llama_index.core.query_engine import SQLAutoVectorQueryEngine
from langchain_text_splitters import RecursiveJsonSplitter
import json
from os import linesep
import json
import pandas as pd
from itertools import chain


# NOTE: This is ONLY necessary in jupyter notebook.
import nest_asyncio

nest_asyncio.apply()

logging.getLogger().setLevel(logging.ERROR)

llama_debug = LlamaDebugHandler(print_trace_on_end=True)
callback_manager = CallbackManager([llama_debug])

Settings.callback_manager = callback_manager

load_dotenv('/Users/sam/dev/spaghetti_dev/MedEd-AI/Credentials/.env')

#Azure OpenAI Creds
endpoint = os.getenv("AZURE_OPENAI_ENDPOINT")
credential = os.getenv("AZURE_OPENAI_API_KEY")
azure_openai_api_version = "2024-04-01-preview"
azure_openai_embedding_deployment = "text-embedding-ada-002"
embedding_model_name = "text-embedding-ada-002"
llm_model_name = "gpt-35-turbo-16k"
api_type = "azure"

#Google Creds
CREDENTIALS_FILE = '../Credentials/credentials.json'
CLIENT_SECRETS_FILE = '../Credentials/client_secret.json'
SCOPES = ['https://www.googleapis.com/auth/forms.body']
DISCOVERY_DOC = "https://forms.googleapis.com/$discovery/rest?version=v1"

user_path = "Users/sam/dev/spaghetti_dev/"

llm = AzureOpenAI(
            model = llm_model_name,
            deployment_name = llm_model_name,
            api_key = credential,
            azure_endpoint = endpoint,
            api_version = azure_openai_api_version,
            api_type = api_type
        )

embed_model = AzureOpenAIEmbedding(
            model = embedding_model_name,
            deployment_name = embedding_model_name,
            api_key = credential,
            azure_endpoint = endpoint,
            api_version = azure_openai_api_version,
            api_type = api_type,
            embed_batch_size=50
        )

Settings.llm = llm
Settings.embed_model = embed_model

# %% [markdown]
# ### Connect / Load DuckDB, Define SQL Query Engine

# %%
# %pip install --upgrade duckdb
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: duckdb in /Users/sam/Library/Python/3.9/lib/python/site-packages (1.0.0)
# DEPRECATION: textract 1.6.5 has a non-standard dependency specifier extract-msg<=0.29.*. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of textract or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Note: you may need to restart the kernel to use updated packages.

# %%
engine = create_engine("duckdb://///Users/sam/dev/spaghetti_dev/MedEd-AI/Data/meded_ai_dev.duckdb", future=True)

metadata_obj = MetaData()

alter_schema = Table('svr_course_quiz_view', 
               metadata_obj, 
               Column("quiz_id", INTEGER), 
               Column('quiz_type', VARCHAR), 
               Column('quiz_title', VARCHAR),
               Column('history_id', BIGINT),
               Column('submission_id', BIGINT),
               Column('student_score', DOUBLE_PRECISION),
                Column('quiz_question_count', BIGINT),
               Column('quiz_points_possible', DOUBLE_PRECISION),
               Column('question_points_possible', DOUBLE_PRECISION),
               Column('answer_points_scored', DOUBLE_PRECISION),
               Column('attempt', BIGINT),
               Column('question_name',VARCHAR),
               Column('question_type', VARCHAR),
               Column('question_text', VARCHAR),
               Column('question_answer', VARCHAR),
               Column('student_answer', VARCHAR),
               autoload_with=engine, 
               extend_existing=True)

with engine.connect() as connection:
    with connection:
        metadata=MetaData()
        my_table=Table("svr_course_quiz_view", metadata, autoload_with=connection)

sql_database = SQLDatabase(engine, include_tables=["svr_course_quiz_view"])

table_node_mapping = SQLTableNodeMapping(sql_database)

table_schema = [SQLTableSchema(table_name='svr_course_quiz_view')]

obj_index = ObjectIndex.from_objects(
    table_schema,
    table_node_mapping,
    VectorStoreIndex,
)

sql_query_engine = SQLTableRetrieverQueryEngine(
    sql_database,
    obj_index.as_retriever(similarity_top_k=1),
)

# %% [markdown]
# ### Test the SQL Query Engine

# %%
response = sql_query_engine.query("what is the quiz_id for CBB 1 Consolidation Assessment Exercise?")
print(response)

# %% [markdown]
# ### Connect to ChromaDB, Create Collection

# %%
remote_db = chromadb.HttpClient(host='localhost',port=8000)
remote_db.delete_collection("quickstart")
chroma_collection = remote_db.get_or_create_collection("quickstart")

# %% [markdown]
# ### Load PDF Course Files, Add Metadata, Create Vector Index

# %%
course_quiz_views = [x for x in glob.glob('/Users/sam/dev/spaghetti_dev/MedEd-AI/Data/coursedata_*/course_quiz_view.json',recursive=True)]

for course_quiz_view in course_quiz_views:
    df = pd.read_json(course_quiz_view)
    df = df.loc[(df['question_type'] == 'essay_question') & (df['quiz_title'].str.contains("Consolidation"))]
    path = course_quiz_view.split('/')
    new_path=[path[0],path[1],path[2],path[3],path[4],path[5],'Data','quizviews',path[7][-6:]+'_'+'cleaned_quiz.json']
    new_path = '/'.join(new_path)
    df.to_json(new_path, 'records')

# %%
[x for x in glob.glob('/Users/sam/dev/spaghetti_dev/MedEd-AI/Data/quizviews/*_cleaned_quiz.json',recursive=True)]

# %%
logging.getLogger().setLevel(logging.WARNING)
pd.set_option('future.no_silent_downcasting', True)
# embed that content, with metadata for where they came from/what consolidation exercise they're a part of 

documents = []

# # process to get cleaned quizzes into text files
# cleaned_quizzes = [x for x in glob.glob('/Users/sam/dev/spaghetti_dev/MedEd-AI/Data/graded_quizzes/graded_quizzes.json',recursive=True)]

# cleaned_quiz = cleaned_quizzes[0]

# json_df = pd.read_json(cleaned_quiz)

# quiz_titles = list(set(json_df['quiz_title'].values))

# for title in quiz_titles:
#     filtered_json_df = json_df.loc[json_df['quiz_title'] == title]
#     title_path = title.replace(" ", "_")
#     quiz_id = str(list(set(filtered_json_df['quiz_id'].values))[0])   
#     questions = list(set(filtered_json_df['question_name'].values))
#     questions.sort()
#     for question in questions:
#         question_name=question.replace(' ','_')
#         with open(f"/Users/sam/dev/spaghetti_dev/MedEd-AI/Data/studentguides/{quiz_id+'_'+str(list(set(filtered_json_df['course_id'].values))[0])+'_'+title_path+'_'+question_name}.txt", "a") as f:
#             f.write(f'Quiz Title: {title}') 
#             f.write(f"\n{question}: {filtered_json_df.loc[(filtered_json_df['quiz_title'] == title) & (filtered_json_df['question_name'] == question)]['question_text'].iat[0].replace('&nbsp;',' ')}")    
#             try:                
#                 f.write(f"\nCorrect Answer: {filtered_json_df.loc[(filtered_json_df['quiz_title'] == title) & (filtered_json_df['question_name'] == question)]['question_answer'].iat[0].replace('Answer: ','').replace('&nbsp;',' ')}")    
#             except:
#                 f.write("\nCorrect Answer: ''")
#             student_responses = filtered_json_df.loc[(filtered_json_df['quiz_title'] == title) & (filtered_json_df['question_name'] == question)]['student_answer'].to_list()
#             student_ids = filtered_json_df.loc[(filtered_json_df['quiz_title'] == title) & (filtered_json_df['question_name'] == question)]['submission_id'].to_list()
#             for i in range(0,len(student_responses)):
#                 try:
#                     f.write(f"\nStudent Answer {student_ids[i]}: {student_responses[i].replace(linesep,'').replace('&nbsp;',' ')}")
#                 except:
#                     pass

reader = SimpleDirectoryReader("/Users/sam/dev/spaghetti_dev/MedEd-AI/Data/studentguides/", recursive=True, filename_as_id=True, required_exts=[".txt",".pdf", ".docx", ".xlsx", ".pptx"])

for docs in reader.iter_data():
    if docs[0].metadata['file_name'].endswith('.txt'):
        for doc in docs:
            quiz_data = '/Users/sam/dev/spaghetti_dev/MedEd-AI/Data/graded_quizzes/graded_quizzes.json'
            quiz_df = pd.read_json(quiz_data)     
            filtered_quiz_df = quiz_df.loc[quiz_df['quiz_id'] == int(docs[0].metadata['file_name'][0:6])]
            doc.metadata.update({'quiz_id': docs[0].metadata['file_name'][0:6], 'course_id': str(list(set(filtered_quiz_df['course_id'].values))[0]), 'quiz_type': 'graded_survey','quiz_title': ' '.join(docs[0].metadata['file_name'].split('_')[2:]).replace('.txt','')})
    else:        
        file_filename = [x for x in glob.glob('/Users/sam/dev/spaghetti_dev/MedEd-AI/Data/coursedata_*/course_file.json',recursive=True) if docs[0].metadata['file_name'][0:6] in x][0]
        file_df = pd.read_json(file_filename)
        file_metadata = file_df.loc[file_df['filename'] == docs[0].metadata['file_name'][7:].replace('_','+')]
        if file_metadata.empty != True:                
            file_metadata = file_metadata.squeeze().to_dict()
            file_metadata = pd.DataFrame(file_metadata, index=[0]).replace(np.NaN, 0).replace(0, None)
            file_metadata = file_metadata.to_dict('records')[0]
            folder = file_metadata.get('folder_id')
        else:
            file_metadata = {}
            folder = ''

        folder_filename = [x for x in glob.glob('/Users/sam/dev/spaghetti_dev/MedEd-AI/Data/coursedata_*/course_folder.json',recursive=True) if docs[0].metadata['file_name'][0:6] in x][0]
        folder_df = pd.read_json(folder_filename)
        folder_metadata = folder_df.loc[folder_df['id'] == folder]
        if folder_metadata.empty != True:
            folder_metadata = folder_metadata.squeeze().to_dict()
            folder_metadata = pd.DataFrame(folder_metadata, index=[0]).replace(np.NaN, 0).replace(0, None)
            folder_metadata = folder_metadata.to_dict('records')[0]
            if 'Week' in folder_metadata['full_name']:
                week = [i for i in folder_metadata['full_name'].split("/") if 'Week' in i][0].replace('Week','').replace(' ','')
                folder_metadata.update({"week":week})
            full_name = folder_metadata['full_name'].split("/")[-1]
            folder_metadata.update({"folder_name":full_name})
        else:
            folder_metadata = {}

        course_filename = [x for x in glob.glob('/Users/sam/dev/spaghetti_dev/MedEd-AI/Data/coursedata_*/course_course.json',recursive=True) if docs[0].metadata['file_name'][0:6] in x][0]
        course_df = pd.read_json(course_filename)        
        course_metadata = course_df.loc[course_df['id'] == folder_metadata.get('context_id')]
        if course_metadata.empty != True:
            course_metadata = course_metadata.squeeze().to_dict()
            course_id = folder_metadata.get('context_id')
        else:
            course_metadata = {}

        for doc in docs:
            doc.metadata.update({"file_id": file_metadata.get('id'), "folder_id":file_metadata.get('folder_id'), "display_name":file_metadata.get('display_name')})
            doc.metadata.update({"week": folder_metadata.get('week'),  "folder_name": folder_metadata.get('folder_name')})
            doc.metadata.update({"course_id": course_metadata.get('id'), "course_name":course_metadata.get('name'),"course_code":course_metadata.get('course_code'),"course_term":course_metadata.get('term', {}).get('name')}) 

    documents.extend(docs)

parser = LangchainNodeParser(RecursiveCharacterTextSplitter(
    # Set a really small chunk size, just to show.
    chunk_size=100,
    chunk_overlap=20,
    length_function=len,
    is_separator_regex=False,
))

nodes = parser.get_nodes_from_documents(documents)

# vector_store = DuckDBVectorStore(nodes=nodes)
vector_store = DuckDBVectorStore()

storage_context = StorageContext.from_defaults(vector_store=vector_store)

vector_index = VectorStoreIndex(nodes, storage_context=storage_context, embed_model=embed_model, llm=llm)
# Out:
# **********
# Trace: index_construction
#     |_embedding -> 1.024633 seconds
#     |_embedding -> 0.949577 seconds
#     |_embedding -> 0.904948 seconds
#     |_embedding -> 0.737422 seconds
#     |_embedding -> 0.575504 seconds
#     |_embedding -> 0.536369 seconds
#     |_embedding -> 0.520297 seconds
#     |_embedding -> 0.71888 seconds
#     |_embedding -> 0.657871 seconds
#     |_embedding -> 0.759617 seconds
#     |_embedding -> 0.610746 seconds
#     |_embedding -> 0.617601 seconds
#     |_embedding -> 0.560672 seconds
#     |_embedding -> 0.498974 seconds
#     |_embedding -> 0.638788 seconds
#     |_embedding -> 0.621618 seconds
#     |_embedding -> 0.568498 seconds
#     |_embedding -> 0.628898 seconds
#     |_embedding -> 0.584668 seconds
#     |_embedding -> 0.560071 seconds
#     |_embedding -> 0.719984 seconds
#     |_embedding -> 0.716676 seconds
#     |_embedding -> 0.567094 seconds
#     |_embedding -> 0.5751 seconds
#     |_embedding -> 0.531464 seconds
#     |_embedding -> 0.488388 seconds
#     |_embedding -> 0.588266 seconds
#     |_embedding -> 0.592905 seconds
#     |_embedding -> 0.54739 seconds
#     |_embedding -> 0.59142 seconds
#     |_embedding -> 0.563522 seconds
#     |_embedding -> 0.61406 seconds
#     |_embedding -> 0.636301 seconds
#     |_embedding -> 0.578831 seconds
#     |_embedding -> 0.567292 seconds
#     |_embedding -> 0.655159 seconds
#     |_embedding -> 0.639803 seconds
#     |_embedding -> 0.501256 seconds
#     |_embedding -> 0.652746 seconds
#     |_embedding -> 0.559854 seconds
#     |_embedding -> 0.540178 seconds
#     |_embedding -> 0.88602 seconds
#     |_embedding -> 0.593199 seconds
#     |_embedding -> 0.549063 seconds
#     |_embedding -> 0.534067 seconds
#     |_embedding -> 0.588766 seconds
#     |_embedding -> 0.600667 seconds
#     |_embedding -> 0.56068 seconds
#     |_embedding -> 0.640727 seconds
#     |_embedding -> 0.542196 seconds
#     |_embedding -> 0.59674 seconds
#     |_embedding -> 0.525523 seconds
#     |_embedding -> 0.601169 seconds
#     |_embedding -> 0.582206 seconds
#     |_embedding -> 0.530327 seconds
#     |_embedding -> 0.486702 seconds
#     |_embedding -> 0.601374 seconds
#     |_embedding -> 0.51282 seconds
#     |_embedding -> 0.54445 seconds
#     |_embedding -> 0.534532 seconds
#     |_embedding -> 0.572392 seconds
#     |_embedding -> 0.58377 seconds
#     |_embedding -> 0.580685 seconds
#     |_embedding -> 0.442999 seconds
#     |_embedding -> 0.426513 seconds
#     |_embedding -> 0.640032 seconds
#     |_embedding -> 0.534021 seconds
#     |_embedding -> 0.626319 seconds
#     |_embedding -> 0.57858 seconds
#     |_embedding -> 0.512823 seconds
#     |_embedding -> 0.60444 seconds
#     |_embedding -> 0.593036 seconds
#     |_embedding -> 0.529868 seconds
#     |_embedding -> 0.524129 seconds
#     |_embedding -> 0.595763 seconds
#     |_embedding -> 0.546423 seconds
#     |_embedding -> 0.537774 seconds
#     |_embedding -> 0.624648 seconds
#     |_embedding -> 0.62764 seconds
#     |_embedding -> 0.53343 seconds
#     |_embedding -> 0.624564 seconds
#     |_embedding -> 0.532303 seconds
#     |_embedding -> 0.801403 seconds
#     |_embedding -> 0.679953 seconds
#     |_embedding -> 0.556602 seconds
#     |_embedding -> 1.368159 seconds
#     |_embedding -> 0.558489 seconds
#     |_embedding -> 0.50795 seconds
#     |_embedding -> 0.450108 seconds
#     |_embedding -> 3.675538 seconds
#     |_embedding -> 0.778962 seconds
#     |_embedding -> 0.561971 seconds
#     |_embedding -> 0.529642 seconds
#     |_embedding -> 0.495247 seconds
#     |_embedding -> 0.545806 seconds
#     |_embedding -> 0.680491 seconds
#     |_embedding -> 0.5216 seconds
#     |_embedding -> 0.518767 seconds
#     |_embedding -> 0.539298 seconds
#     |_embedding -> 0.543384 seconds
#     |_embedding -> 0.509298 seconds
#     |_embedding -> 0.622706 seconds
#     |_embedding -> 0.521349 seconds
#     |_embedding -> 0.518241 seconds
#     |_embedding -> 0.562385 seconds
#     |_embedding -> 0.564587 seconds
#     |_embedding -> 0.522338 seconds
#     |_embedding -> 0.535085 seconds
#     |_embedding -> 0.501557 seconds
#     |_embedding -> 0.624983 seconds
#     |_embedding -> 0.456779 seconds
#     |_embedding -> 0.44487 seconds
#     |_embedding -> 0.467654 seconds
#     |_embedding -> 0.418937 seconds
#     |_embedding -> 0.5242 seconds
#     |_embedding -> 0.531909 seconds
#     |_embedding -> 0.565061 seconds
#     |_embedding -> 0.528541 seconds
#     |_embedding -> 0.545597 seconds
#     |_embedding -> 0.484167 seconds
#     |_embedding -> 0.474645 seconds
#     |_embedding -> 0.57686 seconds
#     |_embedding -> 0.572055 seconds
#     |_embedding -> 0.936636 seconds
#     |_embedding -> 0.53764 seconds
#     |_embedding -> 0.674697 seconds
#     |_embedding -> 0.600091 seconds
#     |_embedding -> 0.601295 seconds
#     |_embedding -> 0.591727 seconds
#     |_embedding -> 0.591533 seconds
#     |_embedding -> 0.505404 seconds
#     |_embedding -> 0.501189 seconds
#     |_embedding -> 0.570441 seconds
#     |_embedding -> 0.543378 seconds
#     |_embedding -> 0.585015 seconds
#     |_embedding -> 0.652836 seconds
#     |_embedding -> 0.608254 seconds
#     |_embedding -> 0.54951 seconds
#     |_embedding -> 0.747052 seconds
#     |_embedding -> 0.537544 seconds
#     |_embedding -> 0.544988 seconds
#     |_embedding -> 0.575786 seconds
#     |_embedding -> 0.555529 seconds
#     |_embedding -> 0.515615 seconds
#     |_embedding -> 0.533312 seconds
#     |_embedding -> 0.60248 seconds
#     |_embedding -> 0.575039 seconds
#     |_embedding -> 0.53849 seconds
#     |_embedding -> 0.554872 seconds
#     |_embedding -> 0.609598 seconds
#     |_embedding -> 0.571097 seconds
#     |_embedding -> 0.620557 seconds
#     |_embedding -> 0.535068 seconds
#     |_embedding -> 0.469653 seconds
#     |_embedding -> 0.447981 seconds
#     |_embedding -> 0.466734 seconds
#     |_embedding -> 0.438225 seconds
#     |_embedding -> 0.420322 seconds
#     |_embedding -> 0.45643 seconds
#     |_embedding -> 0.526166 seconds
#     |_embedding -> 0.462904 seconds
#     |_embedding -> 0.596421 seconds
#     |_embedding -> 0.549392 seconds
#     |_embedding -> 0.531876 seconds
#     |_embedding -> 0.866929 seconds
#     |_embedding -> 1.244985 seconds
#     |_embedding -> 0.556183 seconds
#     |_embedding -> 0.479507 seconds
#     |_embedding -> 0.559251 seconds
#     |_embedding -> 0.557987 seconds
#     |_embedding -> 0.570636 seconds
#     |_embedding -> 0.568188 seconds
#     |_embedding -> 0.602269 seconds
#     |_embedding -> 0.509183 seconds
#     |_embedding -> 0.609181 seconds
#     |_embedding -> 0.646419 seconds
#     |_embedding -> 0.531483 seconds
#     |_embedding -> 0.508499 seconds
#     |_embedding -> 0.533246 seconds
#     |_embedding -> 0.510714 seconds
#     |_embedding -> 0.553635 seconds
#     |_embedding -> 0.544469 seconds
#     |_embedding -> 0.524283 seconds
#     |_embedding -> 0.537851 seconds
#     |_embedding -> 0.636065 seconds
#     |_embedding -> 0.644326 seconds
#     |_embedding -> 0.62807 seconds
#     |_embedding -> 0.61597 seconds
#     |_embedding -> 0.498462 seconds
#     |_embedding -> 0.464959 seconds
#     |_embedding -> 0.462048 seconds
#     |_embedding -> 0.495485 seconds
#     |_embedding -> 0.518567 seconds
#     |_embedding -> 0.64396 seconds
#     |_embedding -> 0.715707 seconds
#     |_embedding -> 0.511124 seconds
#     |_embedding -> 0.512679 seconds
#     |_embedding -> 0.584823 seconds
#     |_embedding -> 0.605615 seconds
#     |_embedding -> 0.583254 seconds
#     |_embedding -> 0.681385 seconds
#     |_embedding -> 0.449436 seconds
#     |_embedding -> 0.609257 seconds
#     |_embedding -> 0.605224 seconds
#     |_embedding -> 0.475269 seconds
#     |_embedding -> 1.75088 seconds
#     |_embedding -> 0.576361 seconds
#     |_embedding -> 0.586779 seconds
#     |_embedding -> 0.675162 seconds
#     |_embedding -> 0.552668 seconds
#     |_embedding -> 0.451638 seconds
#     |_embedding -> 0.648003 seconds
#     |_embedding -> 0.523669 seconds
#     |_embedding -> 0.618191 seconds
#     |_embedding -> 0.651166 seconds
#     |_embedding -> 0.549629 seconds
#     |_embedding -> 0.614143 seconds
#     |_embedding -> 0.497983 seconds
#     |_embedding -> 0.488956 seconds
#     |_embedding -> 0.682104 seconds
#     |_embedding -> 0.639896 seconds
#     |_embedding -> 0.416389 seconds
#     |_embedding -> 0.590193 seconds
#     |_embedding -> 0.575473 seconds
#     |_embedding -> 0.545014 seconds
#     |_embedding -> 0.626489 seconds
#     |_embedding -> 0.624571 seconds
#     |_embedding -> 0.511978 seconds
#     |_embedding -> 0.550846 seconds
#     |_embedding -> 0.593198 seconds
#     |_embedding -> 0.54977 seconds
#     |_embedding -> 0.567957 seconds
#     |_embedding -> 0.582258 seconds
#     |_embedding -> 0.625913 seconds
#     |_embedding -> 0.532222 seconds
#     |_embedding -> 0.544303 seconds
#     |_embedding -> 0.605611 seconds
#     |_embedding -> 0.529595 seconds
#     |_embedding -> 0.669604 seconds
#     |_embedding -> 0.575883 seconds
#     |_embedding -> 0.524325 seconds
#     |_embedding -> 0.675106 seconds
#     |_embedding -> 1.564308 seconds
#     |_embedding -> 0.643854 seconds
#     |_embedding -> 0.582015 seconds
#     |_embedding -> 0.499267 seconds
#     |_embedding -> 0.632037 seconds
#     |_embedding -> 0.425893 seconds
#     |_embedding -> 0.420974 seconds
#     |_embedding -> 0.550616 seconds
#     |_embedding -> 0.508452 seconds
#     |_embedding -> 0.595138 seconds
#     |_embedding -> 0.538199 seconds
#     |_embedding -> 0.48989 seconds
#     |_embedding -> 0.575251 seconds
#     |_embedding -> 0.619216 seconds
#     |_embedding -> 0.515928 seconds
#     |_embedding -> 0.540488 seconds
#     |_embedding -> 0.595877 seconds
#     |_embedding -> 0.47087 seconds
#     |_embedding -> 0.643225 seconds
#     |_embedding -> 0.528615 seconds
#     |_embedding -> 0.597584 seconds
#     |_embedding -> 0.472132 seconds
#     |_embedding -> 0.540691 seconds
#     |_embedding -> 0.626148 seconds
#     |_embedding -> 0.714399 seconds
#     |_embedding -> 0.551385 seconds
#     |_embedding -> 0.502534 seconds
#     |_embedding -> 0.522557 seconds
#     |_embedding -> 0.562336 seconds
#     |_embedding -> 0.524823 seconds
#     |_embedding -> 0.63569 seconds
#     |_embedding -> 0.497363 seconds
#     |_embedding -> 0.5479 seconds
#     |_embedding -> 0.494464 seconds
#     |_embedding -> 0.486652 seconds
#     |_embedding -> 0.620452 seconds
#     |_embedding -> 0.580293 seconds
#     |_embedding -> 0.527876 seconds
#     |_embedding -> 0.573252 seconds
#     |_embedding -> 0.490262 seconds
#     |_embedding -> 0.546974 seconds
#     |_embedding -> 0.424752 seconds
#     |_embedding -> 0.644353 seconds
#     |_embedding -> 0.404133 seconds
#     |_embedding -> 0.426474 seconds
#     |_embedding -> 0.943391 seconds
#     |_embedding -> 0.660216 seconds
#     |_embedding -> 0.5284 seconds
#     |_embedding -> 0.642818 seconds
#     |_embedding -> 0.535819 seconds
#     |_embedding -> 0.534903 seconds
#     |_embedding -> 0.484024 seconds
#     |_embedding -> 0.528491 seconds
#     |_embedding -> 0.555653 seconds
#     |_embedding -> 0.577752 seconds
#     |_embedding -> 0.548143 seconds
#     |_embedding -> 0.510024 seconds
#     |_embedding -> 0.554015 seconds
#     |_embedding -> 1.363466 seconds
#     |_embedding -> 0.511475 seconds
#     |_embedding -> 0.527573 seconds
#     |_embedding -> 0.566217 seconds
#     |_embedding -> 0.483882 seconds
#     |_embedding -> 0.57276 seconds
#     |_embedding -> 0.572373 seconds
#     |_embedding -> 0.609613 seconds
#     |_embedding -> 0.566202 seconds
#     |_embedding -> 0.529335 seconds
#     |_embedding -> 0.659115 seconds
#     |_embedding -> 0.634597 seconds
#     |_embedding -> 0.523381 seconds
#     |_embedding -> 0.650451 seconds
#     |_embedding -> 0.544636 seconds
#     |_embedding -> 0.493346 seconds
#     |_embedding -> 0.580147 seconds
#     |_embedding -> 0.62925 seconds
#     |_embedding -> 0.514797 seconds
#     |_embedding -> 0.502218 seconds
#     |_embedding -> 0.60811 seconds
#     |_embedding -> 0.505184 seconds
#     |_embedding -> 0.629766 seconds
#     |_embedding -> 0.579784 seconds
#     |_embedding -> 0.538262 seconds
#     |_embedding -> 0.650017 seconds
#     |_embedding -> 0.643763 seconds
#     |_embedding -> 1.3312 seconds
#     |_embedding -> 0.648722 seconds
#     |_embedding -> 0.419852 seconds
#     |_embedding -> 0.400775 seconds
#     |_embedding -> 0.464386 seconds
#     |_embedding -> 0.413116 seconds
#     |_embedding -> 0.417567 seconds
#     |_embedding -> 0.469426 seconds
#     |_embedding -> 0.448917 seconds
#     |_embedding -> 0.508349 seconds
#     |_embedding -> 0.523334 seconds
#     |_embedding -> 0.521218 seconds
#     |_embedding -> 0.537548 seconds
#     |_embedding -> 0.542826 seconds
#     |_embedding -> 0.55704 seconds
#     |_embedding -> 0.565961 seconds
#     |_embedding -> 0.525703 seconds
#     |_embedding -> 1.542946 seconds
#     |_embedding -> 0.567406 seconds
#     |_embedding -> 0.50452 seconds
#     |_embedding -> 0.586128 seconds
#     |_embedding -> 0.616687 seconds
#     |_embedding -> 0.542085 seconds
#     |_embedding -> 0.544607 seconds
#     |_embedding -> 0.516425 seconds
#     |_embedding -> 0.479579 seconds
#     |_embedding -> 0.546246 seconds
#     |_embedding -> 0.592253 seconds
#     |_embedding -> 0.51113 seconds
#     |_embedding -> 0.473104 seconds
#     |_embedding -> 0.444647 seconds
#     |_embedding -> 0.431996 seconds
#     |_embedding -> 0.416617 seconds
#     |_embedding -> 0.405394 seconds
#     |_embedding -> 0.570657 seconds
#     |_embedding -> 0.539401 seconds
#     |_embedding -> 0.545993 seconds
#     |_embedding -> 0.53587 seconds
#     |_embedding -> 0.622265 seconds
#     |_embedding -> 0.44235 seconds
#     |_embedding -> 0.505984 seconds
#     |_embedding -> 0.444633 seconds
#     |_embedding -> 0.66293 seconds
#     |_embedding -> 0.416752 seconds
#     |_embedding -> 0.402425 seconds
#     |_embedding -> 1.362914 seconds
#     |_embedding -> 0.401885 seconds
#     |_embedding -> 0.401072 seconds
#     |_embedding -> 0.477136 seconds
#     |_embedding -> 0.468682 seconds
#     |_embedding -> 0.405038 seconds
#     |_embedding -> 0.465165 seconds
#     |_embedding -> 0.459442 seconds
#     |_embedding -> 0.442159 seconds
#     |_embedding -> 0.453985 seconds
#     |_embedding -> 0.403089 seconds
#     |_embedding -> 0.459475 seconds
#     |_embedding -> 0.417602 seconds
#     |_embedding -> 0.443567 seconds
#     |_embedding -> 0.404599 seconds
#     |_embedding -> 0.417517 seconds
#     |_embedding -> 0.418196 seconds
#     |_embedding -> 0.42558 seconds
#     |_embedding -> 0.468318 seconds
#     |_embedding -> 0.422334 seconds
#     |_embedding -> 0.422489 seconds
#     |_embedding -> 0.412532 seconds
#     |_embedding -> 0.458041 seconds
#     |_embedding -> 0.42429 seconds
#     |_embedding -> 0.4056 seconds
#     |_embedding -> 0.458211 seconds
#     |_embedding -> 0.437997 seconds
#     |_embedding -> 0.400172 seconds
#     |_embedding -> 0.44636 seconds
#     |_embedding -> 0.415528 seconds
#     |_embedding -> 0.464864 seconds
#     |_embedding -> 0.438093 seconds
#     |_embedding -> 0.400741 seconds
#     |_embedding -> 0.499968 seconds
#     |_embedding -> 0.429115 seconds
#     |_embedding -> 0.427408 seconds
#     |_embedding -> 0.415977 seconds
#     |_embedding -> 0.571204 seconds
#     |_embedding -> 0.705664 seconds
#     |_embedding -> 0.447293 seconds
#     |_embedding -> 0.428285 seconds
#     |_embedding -> 0.455049 seconds
#     |_embedding -> 0.421538 seconds
#     |_embedding -> 0.422935 seconds
#     |_embedding -> 0.426998 seconds
#     |_embedding -> 0.445488 seconds
#     |_embedding -> 0.467346 seconds
#     |_embedding -> 0.472648 seconds
#     |_embedding -> 0.506461 seconds
#     |_embedding -> 0.423985 seconds
#     |_embedding -> 0.458926 seconds
#     |_embedding -> 1.044636 seconds
#     |_embedding -> 0.439422 seconds
#     |_embedding -> 0.428434 seconds
#     |_embedding -> 0.451546 seconds
#     |_embedding -> 0.538221 seconds
#     |_embedding -> 0.415823 seconds
#     |_embedding -> 0.458779 seconds
#     |_embedding -> 0.497155 seconds
#     |_embedding -> 0.410437 seconds
#     |_embedding -> 0.435973 seconds
#     |_embedding -> 0.417041 seconds
#     |_embedding -> 0.475078 seconds
#     |_embedding -> 0.436516 seconds
#     |_embedding -> 0.434658 seconds
#     |_embedding -> 0.406963 seconds
#     |_embedding -> 0.410618 seconds
#     |_embedding -> 0.418959 seconds
#     |_embedding -> 0.427433 seconds
#     |_embedding -> 0.448613 seconds
#     |_embedding -> 0.396174 seconds
#     |_embedding -> 0.483751 seconds
#     |_embedding -> 3.48763 seconds
#     |_embedding -> 0.432332 seconds
#     |_embedding -> 0.497292 seconds
#     |_embedding -> 0.474213 seconds
#     |_embedding -> 0.504705 seconds
#     |_embedding -> 0.457292 seconds
#     |_embedding -> 0.419432 seconds
#     |_embedding -> 0.658569 seconds
#     |_embedding -> 0.443094 seconds
#     |_embedding -> 0.437747 seconds
#     |_embedding -> 0.435414 seconds
#     |_embedding -> 0.47063 seconds
#     |_embedding -> 0.432123 seconds
#     |_embedding -> 0.454506 seconds
#     |_embedding -> 0.455731 seconds
#     |_embedding -> 0.410687 seconds
#     |_embedding -> 0.435081 seconds
#     |_embedding -> 0.412431 seconds
#     |_embedding -> 0.391274 seconds
#     |_embedding -> 0.425148 seconds
#     |_embedding -> 0.419696 seconds
#     |_embedding -> 0.49486 seconds
#     |_embedding -> 0.408131 seconds
#     |_embedding -> 0.411441 seconds
#     |_embedding -> 0.410457 seconds
#     |_embedding -> 0.501555 seconds
#     |_embedding -> 1.144583 seconds
#     |_embedding -> 0.416358 seconds
#     |_embedding -> 0.411236 seconds
#     |_embedding -> 0.474374 seconds
#     |_embedding -> 0.406567 seconds
#     |_embedding -> 0.459207 seconds
#     |_embedding -> 0.430524 seconds
#     |_embedding -> 0.434669 seconds
#     |_embedding -> 0.38512 seconds
#     |_embedding -> 0.409569 seconds
#     |_embedding -> 0.425823 seconds
#     |_embedding -> 0.558744 seconds
#     |_embedding -> 0.468296 seconds
#     |_embedding -> 0.420896 seconds
#     |_embedding -> 0.443843 seconds
#     |_embedding -> 0.411505 seconds
#     |_embedding -> 0.483146 seconds
#     |_embedding -> 0.400341 seconds
#     |_embedding -> 0.433167 seconds
#     |_embedding -> 0.46807 seconds
#     |_embedding -> 0.412813 seconds
#     |_embedding -> 0.385479 seconds
#     |_embedding -> 0.658304 seconds
#     |_embedding -> 0.455635 seconds
#     |_embedding -> 0.431819 seconds
#     |_embedding -> 0.449244 seconds
#     |_embedding -> 0.456145 seconds
#     |_embedding -> 0.426617 seconds
#     |_embedding -> 0.405181 seconds
#     |_embedding -> 0.427256 seconds
#     |_embedding -> 0.464701 seconds
#     |_embedding -> 0.444687 seconds
#     |_embedding -> 0.406998 seconds
#     |_embedding -> 0.489725 seconds
#     |_embedding -> 0.446746 seconds
#     |_embedding -> 0.451432 seconds
#     |_embedding -> 0.419485 seconds
#     |_embedding -> 0.411587 seconds
#     |_embedding -> 0.451178 seconds
#     |_embedding -> 1.464958 seconds
#     |_embedding -> 0.406142 seconds
#     |_embedding -> 0.480024 seconds
#     |_embedding -> 0.432607 seconds
#     |_embedding -> 0.395154 seconds
#     |_embedding -> 0.419447 seconds
#     |_embedding -> 0.419849 seconds
#     |_embedding -> 1.469727 seconds
#     |_embedding -> 0.443757 seconds
#     |_embedding -> 0.417223 seconds
#     |_embedding -> 0.419554 seconds
#     |_embedding -> 0.405764 seconds
#     |_embedding -> 0.431582 seconds
#     |_embedding -> 0.472827 seconds
#     |_embedding -> 0.432868 seconds
#     |_embedding -> 0.421616 seconds
#     |_embedding -> 0.466908 seconds
#     |_embedding -> 0.422434 seconds
#     |_embedding -> 0.414935 seconds
#     |_embedding -> 0.45979 seconds
#     |_embedding -> 0.425865 seconds
#     |_embedding -> 0.402965 seconds
#     |_embedding -> 0.411817 seconds
#     |_embedding -> 0.374676 seconds
#     |_embedding -> 7.712941 seconds
#     |_embedding -> 0.426114 seconds
#     |_embedding -> 1.048732 seconds
#     |_embedding -> 0.462419 seconds
#     |_embedding -> 0.410351 seconds
#     |_embedding -> 0.434768 seconds
#     |_embedding -> 0.449368 seconds
#     |_embedding -> 0.435599 seconds
#     |_embedding -> 0.410758 seconds
#     |_embedding -> 0.518245 seconds
#     |_embedding -> 0.417875 seconds
#     |_embedding -> 0.434106 seconds
#     |_embedding -> 0.456516 seconds
#     |_embedding -> 0.38862 seconds
#     |_embedding -> 0.437804 seconds
#     |_embedding -> 0.418821 seconds
#     |_embedding -> 0.417599 seconds
#     |_embedding -> 0.46289 seconds
#     |_embedding -> 0.405166 seconds
#     |_embedding -> 0.409147 seconds
#     |_embedding -> 0.398995 seconds
#     |_embedding -> 0.407243 seconds
#     |_embedding -> 0.409078 seconds
#     |_embedding -> 1.489929 seconds
#     |_embedding -> 0.432495 seconds
#     |_embedding -> 0.461921 seconds
#     |_embedding -> 0.422741 seconds
#     |_embedding -> 0.389327 seconds
#     |_embedding -> 1.512551 seconds
#     |_embedding -> 0.426095 seconds
#     |_embedding -> 0.405936 seconds
#     |_embedding -> 0.42343 seconds
#     |_embedding -> 0.407128 seconds
#     |_embedding -> 0.458433 seconds
#     |_embedding -> 0.419688 seconds
#     |_embedding -> 0.397913 seconds
#     |_embedding -> 0.389511 seconds
#     |_embedding -> 0.422371 seconds
#     |_embedding -> 0.412568 seconds
#     |_embedding -> 0.402291 seconds
#     |_embedding -> 0.393756 seconds
#     |_embedding -> 0.655104 seconds
#     |_embedding -> 0.412889 seconds
#     |_embedding -> 0.429243 seconds
#     |_embedding -> 0.407949 seconds
#     |_embedding -> 0.409487 seconds
#     |_embedding -> 0.42211 seconds
#     |_embedding -> 0.4631 seconds
#     |_embedding -> 0.398851 seconds
#     |_embedding -> 0.395913 seconds
#     |_embedding -> 0.396927 seconds
#     |_embedding -> 0.414375 seconds
#     |_embedding -> 0.402365 seconds
#     |_embedding -> 1.157837 seconds
#     |_embedding -> 0.39471 seconds
#     |_embedding -> 0.412451 seconds
#     |_embedding -> 0.404361 seconds
#     |_embedding -> 0.485488 seconds
#     |_embedding -> 0.429594 seconds
#     |_embedding -> 1.389895 seconds
#     |_embedding -> 0.447544 seconds
#     |_embedding -> 0.422779 seconds
#     |_embedding -> 0.418243 seconds
#     |_embedding -> 0.399185 seconds
#     |_embedding -> 3.629785 seconds
#     |_embedding -> 0.641694 seconds
#     |_embedding -> 0.416717 seconds
#     |_embedding -> 0.435154 seconds
#     |_embedding -> 0.415344 seconds
#     |_embedding -> 0.426788 seconds
#     |_embedding -> 0.437375 seconds
#     |_embedding -> 0.568457 seconds
#     |_embedding -> 0.418598 seconds
#     |_embedding -> 0.458626 seconds
#     |_embedding -> 0.540207 seconds
#     |_embedding -> 0.451436 seconds
#     |_embedding -> 0.428979 seconds
#     |_embedding -> 0.451404 seconds
#     |_embedding -> 0.451817 seconds
#     |_embedding -> 0.418083 seconds
#     |_embedding -> 0.420289 seconds
#     |_embedding -> 0.496804 seconds
#     |_embedding -> 0.660339 seconds
#     |_embedding -> 0.426025 seconds
#     |_embedding -> 0.388534 seconds
#     |_embedding -> 0.412118 seconds
#     |_embedding -> 0.43292 seconds
#     |_embedding -> 0.461877 seconds
#     |_embedding -> 0.437534 seconds
#     |_embedding -> 0.411147 seconds
#     |_embedding -> 0.421609 seconds
#     |_embedding -> 0.458521 seconds
#     |_embedding -> 0.411792 seconds
#     |_embedding -> 0.488221 seconds
#     |_embedding -> 0.457585 seconds
#     |_embedding -> 0.439235 seconds
#     |_embedding -> 0.437104 seconds
#     |_embedding -> 0.398838 seconds
#     |_embedding -> 0.447769 seconds
#     |_embedding -> 0.459969 seconds
#     |_embedding -> 0.409422 seconds
#     |_embedding -> 0.408881 seconds
#     |_embedding -> 0.480334 seconds
#     |_embedding -> 0.411413 seconds
#     |_embedding -> 0.449943 seconds
#     |_embedding -> 0.482992 seconds
#     |_embedding -> 0.407023 seconds
#     |_embedding -> 0.413272 seconds
#     |_embedding -> 0.416428 seconds
#     |_embedding -> 0.470104 seconds
#     |_embedding -> 0.41633 seconds
#     |_embedding -> 0.40992 seconds
#     |_embedding -> 0.476051 seconds
#     |_embedding -> 0.428168 seconds
#     |_embedding -> 0.448851 seconds
#     |_embedding -> 0.430395 seconds
#     |_embedding -> 0.474617 seconds
#     |_embedding -> 0.418311 seconds
#     |_embedding -> 0.398457 seconds
#     |_embedding -> 0.409489 seconds
#     |_embedding -> 0.405898 seconds
#     |_embedding -> 0.436668 seconds
#     |_embedding -> 0.399804 seconds
#     |_embedding -> 0.648701 seconds
#     |_embedding -> 0.426452 seconds
#     |_embedding -> 0.460532 seconds
#     |_embedding -> 0.413186 seconds
#     |_embedding -> 0.414079 seconds
#     |_embedding -> 0.403266 seconds
#     |_embedding -> 0.420555 seconds
#     |_embedding -> 0.42053 seconds
#     |_embedding -> 0.457808 seconds
#     |_embedding -> 0.419088 seconds
#     |_embedding -> 0.475201 seconds
#     |_embedding -> 0.388134 seconds
#     |_embedding -> 0.467955 seconds
#     |_embedding -> 0.427139 seconds
#     |_embedding -> 0.439986 seconds
#     |_embedding -> 0.414477 seconds
#     |_embedding -> 0.460998 seconds
#     |_embedding -> 0.470462 seconds
#     |_embedding -> 0.443932 seconds
#     |_embedding -> 0.43937 seconds
#     |_embedding -> 0.408385 seconds
#     |_embedding -> 0.407694 seconds
#     |_embedding -> 0.390739 seconds
#     |_embedding -> 0.400441 seconds
#     |_embedding -> 0.41619 seconds
#     |_embedding -> 0.42614 seconds
#     |_embedding -> 0.452505 seconds
#     |_embedding -> 0.415443 seconds
#     |_embedding -> 0.413303 seconds
#     |_embedding -> 0.424779 seconds
#     |_embedding -> 0.4092 seconds
#     |_embedding -> 0.474118 seconds
#     |_embedding -> 0.415324 seconds
#     |_embedding -> 0.439463 seconds
#     |_embedding -> 0.435461 seconds
#     |_embedding -> 0.437625 seconds
#     |_embedding -> 0.479733 seconds
#     |_embedding -> 0.46204 seconds
#     |_embedding -> 0.418369 seconds
#     |_embedding -> 0.42056 seconds
#     |_embedding -> 0.398445 seconds
#     |_embedding -> 0.634292 seconds
#     |_embedding -> 0.414332 seconds
#     |_embedding -> 0.415906 seconds
#     |_embedding -> 0.468963 seconds
#     |_embedding -> 0.428214 seconds
#     |_embedding -> 0.441522 seconds
#     |_embedding -> 0.483418 seconds
#     |_embedding -> 0.435462 seconds
#     |_embedding -> 0.39217 seconds
#     |_embedding -> 0.389299 seconds
#     |_embedding -> 0.413836 seconds
#     |_embedding -> 0.418883 seconds
#     |_embedding -> 0.473822 seconds
#     |_embedding -> 0.499052 seconds
#     |_embedding -> 0.416393 seconds
#     |_embedding -> 0.427694 seconds
#     |_embedding -> 0.428959 seconds
#     |_embedding -> 0.399367 seconds
#     |_embedding -> 0.416803 seconds
#     |_embedding -> 0.42841 seconds
#     |_embedding -> 0.454803 seconds
#     |_embedding -> 0.466136 seconds
#     |_embedding -> 0.42957 seconds
#     |_embedding -> 0.482303 seconds
#     |_embedding -> 0.447559 seconds
#     |_embedding -> 1.242145 seconds
#     |_embedding -> 0.404189 seconds
#     |_embedding -> 0.449523 seconds
#     |_embedding -> 0.413636 seconds
#     |_embedding -> 0.420752 seconds
#     |_embedding -> 0.422076 seconds
#     |_embedding -> 0.463091 seconds
#     |_embedding -> 0.429688 seconds
#     |_embedding -> 0.434551 seconds
#     |_embedding -> 0.44507 seconds
#     |_embedding -> 0.420381 seconds
#     |_embedding -> 0.450675 seconds
#     |_embedding -> 0.415822 seconds
#     |_embedding -> 0.417757 seconds
#     |_embedding -> 0.461888 seconds
#     |_embedding -> 0.403971 seconds
#     |_embedding -> 0.629069 seconds
#     |_embedding -> 0.452637 seconds
#     |_embedding -> 0.410582 seconds
#     |_embedding -> 0.470744 seconds
#     |_embedding -> 0.414266 seconds
#     |_embedding -> 0.432834 seconds
#     |_embedding -> 0.401037 seconds
#     |_embedding -> 0.414434 seconds
#     |_embedding -> 0.395749 seconds
#     |_embedding -> 0.46334 seconds
#     |_embedding -> 0.425456 seconds
#     |_embedding -> 0.518617 seconds
#     |_embedding -> 0.419864 seconds
#     |_embedding -> 0.407501 seconds
#     |_embedding -> 0.414634 seconds
#     |_embedding -> 0.44639 seconds
#     |_embedding -> 0.471687 seconds
#     |_embedding -> 0.429819 seconds
#     |_embedding -> 0.433339 seconds
#     |_embedding -> 0.401903 seconds
#     |_embedding -> 0.41318 seconds
#     |_embedding -> 0.417243 seconds
#     |_embedding -> 0.419478 seconds
#     |_embedding -> 0.412244 seconds
#     |_embedding -> 0.406358 seconds
#     |_embedding -> 0.483676 seconds
#     |_embedding -> 0.429206 seconds
#     |_embedding -> 0.385539 seconds
#     |_embedding -> 0.412554 seconds
#     |_embedding -> 0.428626 seconds
#     |_embedding -> 0.412559 seconds
#     |_embedding -> 0.46294 seconds
#     |_embedding -> 0.411645 seconds
#     |_embedding -> 0.408328 seconds
#     |_embedding -> 0.597176 seconds
#     |_embedding -> 0.529994 seconds
#     |_embedding -> 0.424665 seconds
#     |_embedding -> 26.069298 seconds
#     |_embedding -> 1.026426 seconds
#     |_embedding -> 1.154465 seconds
#     |_embedding -> 1.356588 seconds
#     |_embedding -> 0.66556 seconds
#     |_embedding -> 0.456243 seconds
#     |_embedding -> 0.45747 seconds
#     |_embedding -> 0.410338 seconds
#     |_embedding -> 0.469025 seconds
#     |_embedding -> 0.436853 seconds
#     |_embedding -> 0.44998 seconds
#     |_embedding -> 0.422663 seconds
#     |_embedding -> 0.427149 seconds
#     |_embedding -> 0.476059 seconds
#     |_embedding -> 0.442052 seconds
#     |_embedding -> 0.420114 seconds
#     |_embedding -> 0.463355 seconds
#     |_embedding -> 0.440851 seconds
#     |_embedding -> 0.412981 seconds
#     |_embedding -> 0.476365 seconds
#     |_embedding -> 0.412606 seconds
#     |_embedding -> 0.408795 seconds
#     |_embedding -> 0.462152 seconds
#     |_embedding -> 0.408476 seconds
#     |_embedding -> 0.517299 seconds
#     |_embedding -> 0.402201 seconds
#     |_embedding -> 0.415868 seconds
#     |_embedding -> 0.4235 seconds
#     |_embedding -> 0.421267 seconds
#     |_embedding -> 0.584582 seconds
#     |_embedding -> 0.413318 seconds
#     |_embedding -> 0.468208 seconds
#     |_embedding -> 0.418502 seconds
#     |_embedding -> 0.557206 seconds
#     |_embedding -> 0.418898 seconds
#     |_embedding -> 0.421527 seconds
#     |_embedding -> 0.461945 seconds
#     |_embedding -> 0.414998 seconds
#     |_embedding -> 0.43096 seconds
#     |_embedding -> 0.407812 seconds
#     |_embedding -> 0.446262 seconds
#     |_embedding -> 0.413073 seconds
#     |_embedding -> 0.418801 seconds
#     |_embedding -> 0.485047 seconds
#     |_embedding -> 0.383931 seconds
#     |_embedding -> 0.648223 seconds
#     |_embedding -> 0.44668 seconds
#     |_embedding -> 0.412115 seconds
#     |_embedding -> 0.460353 seconds
#     |_embedding -> 0.452113 seconds
#     |_embedding -> 0.446998 seconds
#     |_embedding -> 0.405932 seconds
#     |_embedding -> 0.4783 seconds
#     |_embedding -> 0.413089 seconds
#     |_embedding -> 0.42387 seconds
#     |_embedding -> 0.457065 seconds
#     |_embedding -> 0.430428 seconds
#     |_embedding -> 0.451402 seconds
#     |_embedding -> 0.453178 seconds
#     |_embedding -> 0.416047 seconds
#     |_embedding -> 0.433213 seconds
#     |_embedding -> 1.04639 seconds
#     |_embedding -> 0.459283 seconds
#     |_embedding -> 0.418379 seconds
#     |_embedding -> 0.409273 seconds
#     |_embedding -> 0.41365 seconds
#     |_embedding -> 0.432812 seconds
#     |_embedding -> 0.469156 seconds
#     |_embedding -> 0.443255 seconds
#     |_embedding -> 0.424337 seconds
#     |_embedding -> 20.311955 seconds
#     |_embedding -> 0.438964 seconds
#     |_embedding -> 0.45129 seconds
#     |_embedding -> 0.414493 seconds
#     |_embedding -> 0.404484 seconds
#     |_embedding -> 1.44287 seconds
#     |_embedding -> 0.396823 seconds
#     |_embedding -> 0.489538 seconds
#     |_embedding -> 0.43988 seconds
#     |_embedding -> 0.411358 seconds
#     |_embedding -> 0.425663 seconds
#     |_embedding -> 0.40656 seconds
#     |_embedding -> 0.413143 seconds
#     |_embedding -> 0.547237 seconds
#     |_embedding -> 0.438008 seconds
#     |_embedding -> 0.464081 seconds
#     |_embedding -> 0.637671 seconds
#     |_embedding -> 0.432629 seconds
#     |_embedding -> 0.446977 seconds
#     |_embedding -> 0.416784 seconds
#     |_embedding -> 0.413418 seconds
#     |_embedding -> 0.40434 seconds
#     |_embedding -> 0.409594 seconds
#     |_embedding -> 0.472236 seconds
#     |_embedding -> 0.413031 seconds
#     |_embedding -> 0.467875 seconds
#     |_embedding -> 0.397562 seconds
#     |_embedding -> 0.407492 seconds
#     |_embedding -> 0.416748 seconds
#     |_embedding -> 0.402818 seconds
#     |_embedding -> 0.489222 seconds
#     |_embedding -> 0.426006 seconds
#     |_embedding -> 0.439539 seconds
#     |_embedding -> 0.415987 seconds
#     |_embedding -> 0.469302 seconds
#     |_embedding -> 0.554531 seconds
#     |_embedding -> 0.420075 seconds
#     |_embedding -> 0.440863 seconds
#     |_embedding -> 0.544917 seconds
#     |_embedding -> 0.461264 seconds
#     |_embedding -> 0.424595 seconds
#     |_embedding -> 0.426378 seconds
#     |_embedding -> 1.482932 seconds
#     |_embedding -> 0.463085 seconds
#     |_embedding -> 0.467098 seconds
#     |_embedding -> 0.424998 seconds
#     |_embedding -> 0.400448 seconds
#     |_embedding -> 0.426345 seconds
#     |_embedding -> 0.399154 seconds
#     |_embedding -> 0.47228 seconds
#     |_embedding -> 0.410307 seconds
#     |_embedding -> 1.480483 seconds
#     |_embedding -> 0.392826 seconds
#     |_embedding -> 1.218765 seconds
#     |_embedding -> 0.450931 seconds
#     |_embedding -> 0.446214 seconds
#     |_embedding -> 0.38413 seconds
#     |_embedding -> 0.648476 seconds
#     |_embedding -> 0.421559 seconds
#     |_embedding -> 0.419864 seconds
#     |_embedding -> 0.457719 seconds
#     |_embedding -> 0.435337 seconds
#     |_embedding -> 0.474916 seconds
#     |_embedding -> 1.445196 seconds
#     |_embedding -> 0.425854 seconds
#     |_embedding -> 0.422618 seconds
#     |_embedding -> 0.505702 seconds
#     |_embedding -> 0.444534 seconds
#     |_embedding -> 0.407505 seconds
#     |_embedding -> 0.44159 seconds
#     |_embedding -> 0.449 seconds
#     |_embedding -> 0.424689 seconds
#     |_embedding -> 0.529724 seconds
#     |_embedding -> 0.471158 seconds
#     |_embedding -> 1.128212 seconds
#     |_embedding -> 0.467334 seconds
#     |_embedding -> 0.420828 seconds
#     |_embedding -> 0.46224 seconds
#     |_embedding -> 0.434305 seconds
#     |_embedding -> 0.436984 seconds
#     |_embedding -> 0.421373 seconds
#     |_embedding -> 0.403145 seconds
#     |_embedding -> 0.423517 seconds
#     |_embedding -> 0.468421 seconds
#     |_embedding -> 0.405748 seconds
#     |_embedding -> 0.416183 seconds
#     |_embedding -> 0.425946 seconds
#     |_embedding -> 0.406187 seconds
#     |_embedding -> 0.425058 seconds
#     |_embedding -> 0.434 seconds
#     |_embedding -> 0.412553 seconds
#     |_embedding -> 1.469811 seconds
#     |_embedding -> 0.41082 seconds
#     |_embedding -> 0.39576 seconds
#     |_embedding -> 0.453023 seconds
#     |_embedding -> 0.424055 seconds
#     |_embedding -> 0.48774 seconds
#     |_embedding -> 0.40457 seconds
#     |_embedding -> 0.638877 seconds
#     |_embedding -> 0.439625 seconds
#     |_embedding -> 0.418442 seconds
#     |_embedding -> 0.430403 seconds
#     |_embedding -> 0.396863 seconds
#     |_embedding -> 0.417793 seconds
#     |_embedding -> 0.465401 seconds
#     |_embedding -> 0.434947 seconds
#     |_embedding -> 0.398092 seconds
#     |_embedding -> 0.40581 seconds
#     |_embedding -> 0.48441 seconds
#     |_embedding -> 0.41244 seconds
#     |_embedding -> 0.460585 seconds
#     |_embedding -> 0.390372 seconds
#     |_embedding -> 0.425179 seconds
#     |_embedding -> 0.411475 seconds
#     |_embedding -> 1.236088 seconds
#     |_embedding -> 0.420893 seconds
#     |_embedding -> 0.407665 seconds
#     |_embedding -> 0.42241 seconds
#     |_embedding -> 0.420784 seconds
#     |_embedding -> 0.449495 seconds
#     |_embedding -> 0.401185 seconds
#     |_embedding -> 0.427268 seconds
#     |_embedding -> 0.410629 seconds
#     |_embedding -> 0.41817 seconds
#     |_embedding -> 0.411446 seconds
#     |_embedding -> 0.430429 seconds
#     |_embedding -> 0.476807 seconds
#     |_embedding -> 0.578375 seconds
#     |_embedding -> 0.448604 seconds
#     |_embedding -> 0.410175 seconds
#     |_embedding -> 0.38382 seconds
#     |_embedding -> 0.433954 seconds
#     |_embedding -> 0.471465 seconds
#     |_embedding -> 0.448731 seconds
#     |_embedding -> 0.421409 seconds
#     |_embedding -> 0.475756 seconds
#     |_embedding -> 0.415565 seconds
#     |_embedding -> 0.565911 seconds
#     |_embedding -> 0.394995 seconds
#     |_embedding -> 1.831138 seconds
#     |_embedding -> 1.223666 seconds
#     |_embedding -> 0.412529 seconds
#     |_embedding -> 0.439992 seconds
#     |_embedding -> 0.438068 seconds
#     |_embedding -> 0.497729 seconds
#     |_embedding -> 0.435965 seconds
#     |_embedding -> 0.38816 seconds
#     |_embedding -> 0.411669 seconds
#     |_embedding -> 0.421567 seconds
#     |_embedding -> 1.425305 seconds
#     |_embedding -> 0.523425 seconds
#     |_embedding -> 0.412284 seconds
#     |_embedding -> 0.457174 seconds
#     |_embedding -> 0.420342 seconds
#     |_embedding -> 0.426903 seconds
#     |_embedding -> 0.451694 seconds
#     |_embedding -> 0.46555 seconds
#     |_embedding -> 0.410867 seconds
#     |_embedding -> 0.513794 seconds
#     |_embedding -> 0.411169 seconds
#     |_embedding -> 0.400789 seconds
#     |_embedding -> 0.465294 seconds
#     |_embedding -> 0.402674 seconds
#     |_embedding -> 0.420602 seconds
#     |_embedding -> 0.438156 seconds
#     |_embedding -> 3.422494 seconds
#     |_embedding -> 0.453625 seconds
#     |_embedding -> 0.430311 seconds
#     |_embedding -> 1.242223 seconds
#     |_embedding -> 0.427703 seconds
#     |_embedding -> 0.419451 seconds
#     |_embedding -> 0.461419 seconds
#     |_embedding -> 0.405477 seconds
#     |_embedding -> 0.445002 seconds
#     |_embedding -> 0.400129 seconds
#     |_embedding -> 0.48124 seconds
#     |_embedding -> 1.205768 seconds
#     |_embedding -> 0.482995 seconds
#     |_embedding -> 0.434278 seconds
#     |_embedding -> 0.399073 seconds
#     |_embedding -> 0.61924 seconds
#     |_embedding -> 1.433035 seconds
#     |_embedding -> 0.507281 seconds
#     |_embedding -> 0.422033 seconds
#     |_embedding -> 0.491911 seconds
#     |_embedding -> 0.44666 seconds
#     |_embedding -> 1.433662 seconds
#     |_embedding -> 0.397998 seconds
#     |_embedding -> 0.477389 seconds
#     |_embedding -> 0.413811 seconds
#     |_embedding -> 0.431258 seconds
#     |_embedding -> 0.405432 seconds
#     |_embedding -> 0.434407 seconds
#     |_embedding -> 0.42808 seconds
#     |_embedding -> 0.477759 seconds
#     |_embedding -> 0.419016 seconds
#     |_embedding -> 0.447551 seconds
#     |_embedding -> 0.414149 seconds
#     |_embedding -> 0.414011 seconds
#     |_embedding -> 0.445938 seconds
#     |_embedding -> 0.466591 seconds
#     |_embedding -> 0.430461 seconds
#     |_embedding -> 0.583374 seconds
#     |_embedding -> 0.431034 seconds
#     |_embedding -> 0.452162 seconds
#     |_embedding -> 0.404153 seconds
#     |_embedding -> 0.401373 seconds
#     |_embedding -> 0.464769 seconds
#     |_embedding -> 0.488398 seconds
#     |_embedding -> 0.417415 seconds
#     |_embedding -> 0.455465 seconds
#     |_embedding -> 0.419235 seconds
#     |_embedding -> 0.478658 seconds
#     |_embedding -> 0.441476 seconds
#     |_embedding -> 0.425329 seconds
#     |_embedding -> 0.426341 seconds
#     |_embedding -> 0.407833 seconds
#     |_embedding -> 0.503239 seconds
#     |_embedding -> 1.435202 seconds
#     |_embedding -> 0.433412 seconds
#     |_embedding -> 0.402866 seconds
#     |_embedding -> 0.616101 seconds
#     |_embedding -> 2.460913 seconds
#     |_embedding -> 0.448573 seconds
#     |_embedding -> 1.175369 seconds
#     |_embedding -> 1.025754 seconds
#     |_embedding -> 0.42914 seconds
#     |_embedding -> 0.479713 seconds
#     |_embedding -> 0.452863 seconds
#     |_embedding -> 0.420617 seconds
#     |_embedding -> 1.443591 seconds
#     |_embedding -> 0.398529 seconds
#     |_embedding -> 0.500247 seconds
#     |_embedding -> 0.409294 seconds
#     |_embedding -> 0.432474 seconds
#     |_embedding -> 0.485038 seconds
#     |_embedding -> 1.19614 seconds
#     |_embedding -> 0.439431 seconds
#     |_embedding -> 0.40047 seconds
#     |_embedding -> 0.406234 seconds
#     |_embedding -> 0.43956 seconds
#     |_embedding -> 0.412151 seconds
#     |_embedding -> 0.501608 seconds
#     |_embedding -> 1.348956 seconds
#     |_embedding -> 0.400679 seconds
#     |_embedding -> 0.414121 seconds
#     |_embedding -> 0.44216 seconds
#     |_embedding -> 0.438672 seconds
#     |_embedding -> 0.446896 seconds
#     |_embedding -> 0.446231 seconds
#     |_embedding -> 0.472115 seconds
#     |_embedding -> 0.424948 seconds
#     |_embedding -> 0.400096 seconds
#     |_embedding -> 0.4527 seconds
#     |_embedding -> 0.44112 seconds
#     |_embedding -> 0.418565 seconds
#     |_embedding -> 0.39795 seconds
#     |_embedding -> 0.443513 seconds
#     |_embedding -> 0.428709 seconds
#     |_embedding -> 0.438482 seconds
#     |_embedding -> 0.45825 seconds
#     |_embedding -> 0.401417 seconds
#     |_embedding -> 0.62578 seconds
#     |_embedding -> 0.420558 seconds
#     |_embedding -> 0.410224 seconds
#     |_embedding -> 0.516348 seconds
#     |_embedding -> 0.448308 seconds
#     |_embedding -> 0.413125 seconds
#     |_embedding -> 0.401824 seconds
#     |_embedding -> 0.421337 seconds
#     |_embedding -> 0.416759 seconds
#     |_embedding -> 0.417828 seconds
#     |_embedding -> 0.449293 seconds
#     |_embedding -> 0.507839 seconds
#     |_embedding -> 0.417124 seconds
#     |_embedding -> 0.428984 seconds
#     |_embedding -> 0.442198 seconds
#     |_embedding -> 0.404385 seconds
#     |_embedding -> 0.46887 seconds
#     |_embedding -> 0.445954 seconds
#     |_embedding -> 0.406358 seconds
#     |_embedding -> 0.415751 seconds
#     |_embedding -> 0.49109 seconds
#     |_embedding -> 0.424866 seconds
#     |_embedding -> 0.42103 seconds
#     |_embedding -> 0.41654 seconds
#     |_embedding -> 0.471042 seconds
#     |_embedding -> 0.422969 seconds
#     |_embedding -> 0.423672 seconds
#     |_embedding -> 0.54784 seconds
#     |_embedding -> 0.422192 seconds
#     |_embedding -> 0.450203 seconds
#     |_embedding -> 0.406936 seconds
#     |_embedding -> 0.426596 seconds
#     |_embedding -> 0.408283 seconds
#     |_embedding -> 0.404366 seconds
#     |_embedding -> 0.454516 seconds
#     |_embedding -> 0.466397 seconds
#     |_embedding -> 1.436382 seconds
#     |_embedding -> 0.409238 seconds
#     |_embedding -> 0.447652 seconds
#     |_embedding -> 0.464309 seconds
#     |_embedding -> 0.390383 seconds
#     |_embedding -> 0.615787 seconds
#     |_embedding -> 0.422242 seconds
#     |_embedding -> 0.406803 seconds
#     |_embedding -> 1.434812 seconds
#     |_embedding -> 0.459783 seconds
#     |_embedding -> 0.424774 seconds
#     |_embedding -> 0.44709 seconds
#     |_embedding -> 0.410425 seconds
#     |_embedding -> 0.411403 seconds
#     |_embedding -> 0.416037 seconds
#     |_embedding -> 0.40726 seconds
#     |_embedding -> 0.479327 seconds
#     |_embedding -> 0.417423 seconds
#     |_embedding -> 0.431442 seconds
#     |_embedding -> 0.461759 seconds
#     |_embedding -> 0.396364 seconds
#     |_embedding -> 0.425756 seconds
#     |_embedding -> 0.399721 seconds
#     |_embedding -> 0.527598 seconds
#     |_embedding -> 0.471625 seconds
#     |_embedding -> 0.415569 seconds
#     |_embedding -> 0.43856 seconds
#     |_embedding -> 0.421795 seconds
#     |_embedding -> 1.508226 seconds
#     |_embedding -> 0.476261 seconds
#     |_embedding -> 0.433939 seconds
#     |_embedding -> 0.460317 seconds
#     |_embedding -> 0.414127 seconds
#     |_embedding -> 0.427574 seconds
#     |_embedding -> 0.416672 seconds
#     |_embedding -> 0.407775 seconds
#     |_embedding -> 0.464339 seconds
#     |_embedding -> 0.41777 seconds
#     |_embedding -> 0.450282 seconds
#     |_embedding -> 0.42818 seconds
#     |_embedding -> 0.453322 seconds
#     |_embedding -> 0.453314 seconds
#     |_embedding -> 0.413278 seconds
#     |_embedding -> 1.423674 seconds
#     |_embedding -> 0.418465 seconds
#     |_embedding -> 0.399958 seconds
#     |_embedding -> 0.839111 seconds
#     |_embedding -> 1.509351 seconds
#     |_embedding -> 0.537999 seconds
#     |_embedding -> 2.007391 seconds
#     |_embedding -> 0.604435 seconds
#     |_embedding -> 0.439224 seconds
#     |_embedding -> 0.404544 seconds
#     |_embedding -> 0.53195 seconds
#     |_embedding -> 0.460814 seconds
#     |_embedding -> 0.433062 seconds
#     |_embedding -> 0.539567 seconds
#     |_embedding -> 0.407936 seconds
#     |_embedding -> 0.78084 seconds
#     |_embedding -> 0.413308 seconds
#     |_embedding -> 0.433169 seconds
#     |_embedding -> 0.408 seconds
#     |_embedding -> 0.453205 seconds
#     |_embedding -> 0.388665 seconds
#     |_embedding -> 0.467699 seconds
#     |_embedding -> 0.40993 seconds
#     |_embedding -> 0.410084 seconds
#     |_embedding -> 0.453382 seconds
#     |_embedding -> 0.412677 seconds
#     |_embedding -> 0.427591 seconds
#     |_embedding -> 0.476083 seconds
#     |_embedding -> 0.43701 seconds
#     |_embedding -> 0.406564 seconds
#     |_embedding -> 0.433661 seconds
#     |_embedding -> 0.447792 seconds
#     |_embedding -> 0.391609 seconds
#     |_embedding -> 0.415412 seconds
#     |_embedding -> 0.577452 seconds
#     |_embedding -> 0.462516 seconds
#     |_embedding -> 0.430159 seconds
#     |_embedding -> 0.457918 seconds
#     |_embedding -> 0.401968 seconds
#     |_embedding -> 0.404008 seconds
#     |_embedding -> 0.454626 seconds
#     |_embedding -> 0.411784 seconds
#     |_embedding -> 0.428691 seconds
#     |_embedding -> 0.395539 seconds
#     |_embedding -> 0.606063 seconds
#     |_embedding -> 0.420186 seconds
#     |_embedding -> 0.426917 seconds
#     |_embedding -> 0.408321 seconds
#     |_embedding -> 1.439297 seconds
#     |_embedding -> 0.437775 seconds
#     |_embedding -> 0.424382 seconds
#     |_embedding -> 0.46429 seconds
#     |_embedding -> 0.401117 seconds
#     |_embedding -> 0.407058 seconds
#     |_embedding -> 0.421519 seconds
#     |_embedding -> 0.449633 seconds
#     |_embedding -> 0.405916 seconds
#     |_embedding -> 0.39466 seconds
#     |_embedding -> 0.411993 seconds
#     |_embedding -> 0.448706 seconds
#     |_embedding -> 0.405942 seconds
#     |_embedding -> 0.426139 seconds
#     |_embedding -> 0.419208 seconds
#     |_embedding -> 0.430083 seconds
#     |_embedding -> 0.573824 seconds
#     |_embedding -> 0.421512 seconds
#     |_embedding -> 0.421223 seconds
#     |_embedding -> 0.400948 seconds
#     |_embedding -> 0.393059 seconds
#     |_embedding -> 0.411571 seconds
#     |_embedding -> 1.517758 seconds
#     |_embedding -> 0.412048 seconds
#     |_embedding -> 0.421191 seconds
#     |_embedding -> 0.429654 seconds
#     |_embedding -> 0.468803 seconds
#     |_embedding -> 0.443821 seconds
#     |_embedding -> 0.424777 seconds
#     |_embedding -> 0.424968 seconds
#     |_embedding -> 0.418048 seconds
#     |_embedding -> 0.408938 seconds
#     |_embedding -> 0.41883 seconds
#     |_embedding -> 0.480862 seconds
#     |_embedding -> 0.4378 seconds
#     |_embedding -> 0.457338 seconds
#     |_embedding -> 0.39143 seconds
#     |_embedding -> 0.65317 seconds
#     |_embedding -> 0.411311 seconds
#     |_embedding -> 0.432666 seconds
#     |_embedding -> 0.421803 seconds
#     |_embedding -> 0.437601 seconds
#     |_embedding -> 0.446271 seconds
#     |_embedding -> 0.41933 seconds
#     |_embedding -> 0.418942 seconds
#     |_embedding -> 0.414385 seconds
#     |_embedding -> 0.420447 seconds
#     |_embedding -> 0.460541 seconds
#     |_embedding -> 0.404778 seconds
#     |_embedding -> 1.596918 seconds
#     |_embedding -> 0.418791 seconds
#     |_embedding -> 0.459556 seconds
#     |_embedding -> 0.441803 seconds
#     |_embedding -> 0.405847 seconds
#     |_embedding -> 0.433992 seconds
#     |_embedding -> 0.409663 seconds
#     |_embedding -> 0.452911 seconds
#     |_embedding -> 0.411448 seconds
#     |_embedding -> 0.41044 seconds
#     |_embedding -> 0.434326 seconds
#     |_embedding -> 0.403 seconds
#     |_embedding -> 0.450129 seconds
#     |_embedding -> 0.444205 seconds
#     |_embedding -> 0.421093 seconds
#     |_embedding -> 1.53649 seconds
#     |_embedding -> 0.435832 seconds
#     |_embedding -> 0.442221 seconds
#     |_embedding -> 0.43162 seconds
#     |_embedding -> 0.427478 seconds
#     |_embedding -> 0.529723 seconds
#     |_embedding -> 0.426391 seconds
#     |_embedding -> 0.444743 seconds
#     |_embedding -> 0.470072 seconds
#     |_embedding -> 0.417557 seconds
#     |_embedding -> 0.754387 seconds
#     |_embedding -> 0.421657 seconds
#     |_embedding -> 0.424002 seconds
#     |_embedding -> 0.398571 seconds
#     |_embedding -> 0.617215 seconds
#     |_embedding -> 1.423929 seconds
#     |_embedding -> 0.411471 seconds
#     |_embedding -> 0.418894 seconds
#     |_embedding -> 0.476168 seconds
#     |_embedding -> 0.413416 seconds
#     |_embedding -> 0.438155 seconds
#     |_embedding -> 0.434166 seconds
#     |_embedding -> 0.437719 seconds
#     |_embedding -> 0.438785 seconds
#     |_embedding -> 0.412116 seconds
#     |_embedding -> 0.462347 seconds
#     |_embedding -> 0.389124 seconds
#     |_embedding -> 0.393144 seconds
#     |_embedding -> 0.426292 seconds
#     |_embedding -> 0.404415 seconds
#     |_embedding -> 0.409588 seconds
#     |_embedding -> 0.44804 seconds
#     |_embedding -> 0.411354 seconds
#     |_embedding -> 0.446412 seconds
#     |_embedding -> 0.491122 seconds
#     |_embedding -> 0.425944 seconds
#     |_embedding -> 0.4394 seconds
#     |_embedding -> 0.43435 seconds
#     |_embedding -> 0.416004 seconds
# ...
#     |_embedding -> 0.463057 seconds
#     |_embedding -> 0.425924 seconds
#     |_embedding -> 0.425036 seconds
#     |_embedding -> 0.403879 seconds
#     |_embedding -> 0.552363 seconds
#     |_embedding -> 0.442533 seconds
#     |_embedding -> 0.425224 seconds
#     |_embedding -> 0.416258 seconds
#     |_embedding -> 0.473775 seconds
#     |_embedding -> 1.441258 seconds
#     |_embedding -> 0.418639 seconds
#     |_embedding -> 0.412124 seconds
#     |_embedding -> 0.430364 seconds
#     |_embedding -> 0.47102 seconds
#     |_embedding -> 0.435539 seconds
#     |_embedding -> 0.430222 seconds
#     |_embedding -> 0.44564 seconds
#     |_embedding -> 0.439252 seconds
#     |_embedding -> 0.438409 seconds
#     |_embedding -> 0.429059 seconds
#     |_embedding -> 0.401514 seconds
#     |_embedding -> 0.62158 seconds
#     |_embedding -> 0.434909 seconds
#     |_embedding -> 0.457139 seconds
#     |_embedding -> 0.417712 seconds
#     |_embedding -> 0.391622 seconds
#     |_embedding -> 0.40729 seconds
#     |_embedding -> 0.398637 seconds
#     |_embedding -> 0.418583 seconds
#     |_embedding -> 0.40695 seconds
#     |_embedding -> 0.456067 seconds
#     |_embedding -> 0.449903 seconds
#     |_embedding -> 0.594706 seconds
#     |_embedding -> 0.395866 seconds
#     |_embedding -> 0.427376 seconds
#     |_embedding -> 0.565049 seconds
#     |_embedding -> 0.419291 seconds
#     |_embedding -> 0.422877 seconds
#     |_embedding -> 0.466083 seconds
#     |_embedding -> 0.407494 seconds
#     |_embedding -> 0.399959 seconds
#     |_embedding -> 0.407311 seconds
#     |_embedding -> 0.430547 seconds
#     |_embedding -> 0.41911 seconds
#     |_embedding -> 0.414133 seconds
#     |_embedding -> 0.450699 seconds
#     |_embedding -> 0.388496 seconds
#     |_embedding -> 0.401561 seconds
#     |_embedding -> 0.476173 seconds
#     |_embedding -> 0.420256 seconds
#     |_embedding -> 0.440081 seconds
#     |_embedding -> 0.442144 seconds
#     |_embedding -> 0.419332 seconds
#     |_embedding -> 0.452896 seconds
#     |_embedding -> 0.466032 seconds
#     |_embedding -> 0.454525 seconds
#     |_embedding -> 0.44294 seconds
#     |_embedding -> 0.448318 seconds
#     |_embedding -> 0.478944 seconds
#     |_embedding -> 0.421521 seconds
#     |_embedding -> 0.445739 seconds
#     |_embedding -> 0.399906 seconds
#     |_embedding -> 0.625771 seconds
#     |_embedding -> 0.429615 seconds
#     |_embedding -> 0.415525 seconds
#     |_embedding -> 0.470999 seconds
#     |_embedding -> 0.453684 seconds
#     |_embedding -> 0.435129 seconds
#     |_embedding -> 0.426971 seconds
#     |_embedding -> 0.431101 seconds
#     |_embedding -> 0.459353 seconds
#     |_embedding -> 0.431377 seconds
#     |_embedding -> 0.413809 seconds
#     |_embedding -> 0.409691 seconds
#     |_embedding -> 0.497994 seconds
#     |_embedding -> 0.413656 seconds
#     |_embedding -> 1.389999 seconds
#     |_embedding -> 0.454699 seconds
#     |_embedding -> 1.196821 seconds
#     |_embedding -> 0.399711 seconds
#     |_embedding -> 1.506723 seconds
#     |_embedding -> 0.405323 seconds
#     |_embedding -> 0.443214 seconds
#     |_embedding -> 0.454733 seconds
#     |_embedding -> 0.39571 seconds
#     |_embedding -> 0.435473 seconds
#     |_embedding -> 0.407344 seconds
#     |_embedding -> 0.471805 seconds
#     |_embedding -> 0.416518 seconds
#     |_embedding -> 0.423285 seconds
#     |_embedding -> 0.469302 seconds
#     |_embedding -> 0.420505 seconds
#     |_embedding -> 0.407168 seconds
#     |_embedding -> 0.456342 seconds
#     |_embedding -> 0.417509 seconds
#     |_embedding -> 0.397132 seconds
#     |_embedding -> 0.424815 seconds
#     |_embedding -> 0.434939 seconds
#     |_embedding -> 0.407339 seconds
#     |_embedding -> 0.442383 seconds
#     |_embedding -> 0.422117 seconds
#     |_embedding -> 0.429885 seconds
#     |_embedding -> 0.402785 seconds
#     |_embedding -> 0.623104 seconds
#     |_embedding -> 0.467759 seconds
#     |_embedding -> 1.335571 seconds
#     |_embedding -> 0.416837 seconds
#     |_embedding -> 0.605351 seconds
#     |_embedding -> 0.404258 seconds
#     |_embedding -> 0.416187 seconds
#     |_embedding -> 0.426501 seconds
#     |_embedding -> 0.46429 seconds
#     |_embedding -> 0.423758 seconds
#     |_embedding -> 0.427097 seconds
#     |_embedding -> 0.416618 seconds
#     |_embedding -> 0.47947 seconds
#     |_embedding -> 0.409543 seconds
#     |_embedding -> 0.410685 seconds
#     |_embedding -> 0.492351 seconds
#     |_embedding -> 0.434051 seconds
#     |_embedding -> 0.406681 seconds
#     |_embedding -> 0.429036 seconds
#     |_embedding -> 0.434099 seconds
#     |_embedding -> 0.419589 seconds
#     |_embedding -> 0.39452 seconds
#     |_embedding -> 0.391971 seconds
#     |_embedding -> 0.39539 seconds
#     |_embedding -> 0.402201 seconds
#     |_embedding -> 0.435882 seconds
#     |_embedding -> 0.412642 seconds
#     |_embedding -> 0.403929 seconds
#     |_embedding -> 0.452147 seconds
#     |_embedding -> 1.300333 seconds
#     |_embedding -> 0.404879 seconds
#     |_embedding -> 0.457776 seconds
#     |_embedding -> 0.400536 seconds
#     |_embedding -> 0.427138 seconds
#     |_embedding -> 0.466343 seconds
#     |_embedding -> 1.033793 seconds
#     |_embedding -> 0.413484 seconds
#     |_embedding -> 0.475298 seconds
#     |_embedding -> 0.389545 seconds
#     |_embedding -> 0.393994 seconds
#     |_embedding -> 1.255474 seconds
#     |_embedding -> 0.616102 seconds
#     |_embedding -> 0.399787 seconds
#     |_embedding -> 0.408634 seconds
#     |_embedding -> 0.465579 seconds
#     |_embedding -> 0.423666 seconds
#     |_embedding -> 0.433923 seconds
#     |_embedding -> 0.522553 seconds
#     |_embedding -> 0.41626 seconds
#     |_embedding -> 0.413953 seconds
#     |_embedding -> 0.420064 seconds
#     |_embedding -> 0.403447 seconds
#     |_embedding -> 0.472724 seconds
#     |_embedding -> 0.419204 seconds
#     |_embedding -> 0.440082 seconds
#     |_embedding -> 0.441074 seconds
#     |_embedding -> 0.445537 seconds
#     |_embedding -> 0.820666 seconds
#     |_embedding -> 0.416931 seconds
#     |_embedding -> 0.446136 seconds
#     |_embedding -> 0.484316 seconds
#     |_embedding -> 0.412603 seconds
#     |_embedding -> 0.414481 seconds
#     |_embedding -> 0.486354 seconds
#     |_embedding -> 0.421573 seconds
#     |_embedding -> 0.422498 seconds
#     |_embedding -> 0.425246 seconds
#     |_embedding -> 0.406791 seconds
#     |_embedding -> 0.43446 seconds
#     |_embedding -> 0.468959 seconds
#     |_embedding -> 0.446985 seconds
#     |_embedding -> 1.117632 seconds
#     |_embedding -> 0.409302 seconds
#     |_embedding -> 2.363788 seconds
#     |_embedding -> 0.46419 seconds
#     |_embedding -> 1.288086 seconds
#     |_embedding -> 0.452691 seconds
#     |_embedding -> 0.424651 seconds
#     |_embedding -> 0.417953 seconds
#     |_embedding -> 0.424883 seconds
#     |_embedding -> 0.454902 seconds
#     |_embedding -> 0.385445 seconds
#     |_embedding -> 0.684301 seconds
#     |_embedding -> 0.423837 seconds
#     |_embedding -> 0.447634 seconds
#     |_embedding -> 0.419669 seconds
#     |_embedding -> 0.443488 seconds
#     |_embedding -> 0.419575 seconds
#     |_embedding -> 0.449256 seconds
#     |_embedding -> 0.468112 seconds
#     |_embedding -> 0.424755 seconds
#     |_embedding -> 0.412199 seconds
#     |_embedding -> 0.446916 seconds
#     |_embedding -> 0.451948 seconds
#     |_embedding -> 0.456539 seconds
#     |_embedding -> 0.440728 seconds
#     |_embedding -> 0.409421 seconds
#     |_embedding -> 0.560055 seconds
#     |_embedding -> 0.416065 seconds
#     |_embedding -> 0.413793 seconds
#     |_embedding -> 0.470464 seconds
#     |_embedding -> 0.439989 seconds
#     |_embedding -> 0.408447 seconds
#     |_embedding -> 0.418479 seconds
#     |_embedding -> 0.467024 seconds
#     |_embedding -> 0.425752 seconds
#     |_embedding -> 0.432309 seconds
#     |_embedding -> 0.478113 seconds
#     |_embedding -> 0.461519 seconds
#     |_embedding -> 0.43543 seconds
#     |_embedding -> 0.570439 seconds
#     |_embedding -> 0.445167 seconds
#     |_embedding -> 0.459919 seconds
#     |_embedding -> 0.438438 seconds
#     |_embedding -> 0.469985 seconds
#     |_embedding -> 0.404004 seconds
#     |_embedding -> 0.419657 seconds
#     |_embedding -> 0.479106 seconds
#     |_embedding -> 0.424166 seconds
#     |_embedding -> 0.463989 seconds
#     |_embedding -> 0.39222 seconds
#     |_embedding -> 0.407385 seconds
#     |_embedding -> 0.415702 seconds
#     |_embedding -> 0.653254 seconds
#     |_embedding -> 0.420693 seconds
#     |_embedding -> 0.412184 seconds
#     |_embedding -> 0.404447 seconds
#     |_embedding -> 0.446781 seconds
#     |_embedding -> 0.421839 seconds
#     |_embedding -> 0.432732 seconds
#     |_embedding -> 0.497782 seconds
#     |_embedding -> 0.536367 seconds
#     |_embedding -> 0.405253 seconds
#     |_embedding -> 0.447326 seconds
#     |_embedding -> 0.440823 seconds
#     |_embedding -> 0.417591 seconds
#     |_embedding -> 0.403736 seconds
#     |_embedding -> 0.467866 seconds
#     |_embedding -> 0.417455 seconds
#     |_embedding -> 0.419279 seconds
#     |_embedding -> 0.438355 seconds
#     |_embedding -> 0.483826 seconds
#     |_embedding -> 0.399367 seconds
#     |_embedding -> 0.391714 seconds
#     |_embedding -> 0.403203 seconds
#     |_embedding -> 0.397373 seconds
#     |_embedding -> 0.404593 seconds
#     |_embedding -> 0.430145 seconds
#     |_embedding -> 0.393497 seconds
#     |_embedding -> 0.523065 seconds
#     |_embedding -> 0.525107 seconds
#     |_embedding -> 0.409821 seconds
#     |_embedding -> 1.439496 seconds
#     |_embedding -> 0.47286 seconds
#     |_embedding -> 0.417014 seconds
#     |_embedding -> 0.442987 seconds
#     |_embedding -> 0.429141 seconds
#     |_embedding -> 0.421907 seconds
#     |_embedding -> 0.412204 seconds
#     |_embedding -> 0.458633 seconds
#     |_embedding -> 0.422592 seconds
#     |_embedding -> 0.455851 seconds
#     |_embedding -> 0.43038 seconds
#     |_embedding -> 0.387907 seconds
#     |_embedding -> 0.641206 seconds
#     |_embedding -> 0.463709 seconds
#     |_embedding -> 0.425471 seconds
#     |_embedding -> 0.461419 seconds
#     |_embedding -> 0.400977 seconds
#     |_embedding -> 0.410071 seconds
#     |_embedding -> 0.417802 seconds
#     |_embedding -> 0.415203 seconds
#     |_embedding -> 0.411182 seconds
#     |_embedding -> 0.481339 seconds
#     |_embedding -> 0.423719 seconds
#     |_embedding -> 0.450618 seconds
#     |_embedding -> 0.413039 seconds
#     |_embedding -> 0.413422 seconds
#     |_embedding -> 0.457098 seconds
#     |_embedding -> 0.418387 seconds
#     |_embedding -> 0.444825 seconds
#     |_embedding -> 0.457999 seconds
#     |_embedding -> 0.422058 seconds
#     |_embedding -> 0.421771 seconds
#     |_embedding -> 0.5058 seconds
#     |_embedding -> 0.442717 seconds
#     |_embedding -> 0.467073 seconds
#     |_embedding -> 0.41812 seconds
#     |_embedding -> 0.471235 seconds
#     |_embedding -> 0.428762 seconds
#     |_embedding -> 0.442132 seconds
#     |_embedding -> 0.421955 seconds
#     |_embedding -> 0.448015 seconds
#     |_embedding -> 0.422697 seconds
#     |_embedding -> 0.477199 seconds
#     |_embedding -> 0.442805 seconds
#     |_embedding -> 0.447819 seconds
#     |_embedding -> 0.435399 seconds
#     |_embedding -> 0.465881 seconds
#     |_embedding -> 0.387212 seconds
#     |_embedding -> 0.39902 seconds
#     |_embedding -> 0.411903 seconds
#     |_embedding -> 0.431875 seconds
#     |_embedding -> 0.405729 seconds
#     |_embedding -> 0.393344 seconds
#     |_embedding -> 0.787713 seconds
#     |_embedding -> 0.568345 seconds
#     |_embedding -> 1.280651 seconds
#     |_embedding -> 0.46019 seconds
#     |_embedding -> 0.452248 seconds
#     |_embedding -> 0.461764 seconds
#     |_embedding -> 0.451298 seconds
#     |_embedding -> 0.460652 seconds
#     |_embedding -> 0.41888 seconds
#     |_embedding -> 0.436503 seconds
#     |_embedding -> 1.114096 seconds
#     |_embedding -> 1.102701 seconds
#     |_embedding -> 0.415913 seconds
#     |_embedding -> 0.411938 seconds
#     |_embedding -> 0.469136 seconds
#     |_embedding -> 0.419593 seconds
#     |_embedding -> 0.448196 seconds
#     |_embedding -> 0.449933 seconds
#     |_embedding -> 0.414182 seconds
#     |_embedding -> 0.471828 seconds
#     |_embedding -> 0.44475 seconds
#     |_embedding -> 0.401767 seconds
#     |_embedding -> 0.443234 seconds
#     |_embedding -> 0.403352 seconds
#     |_embedding -> 1.447595 seconds
#     |_embedding -> 0.404955 seconds
#     |_embedding -> 0.421245 seconds
#     |_embedding -> 0.431542 seconds
#     |_embedding -> 0.456657 seconds
#     |_embedding -> 0.423977 seconds
#     |_embedding -> 0.424996 seconds
#     |_embedding -> 0.429116 seconds
#     |_embedding -> 0.386863 seconds
#     |_embedding -> 0.4033 seconds
#     |_embedding -> 0.482319 seconds
#     |_embedding -> 0.404715 seconds
#     |_embedding -> 0.427094 seconds
#     |_embedding -> 0.403949 seconds
#     |_embedding -> 0.435171 seconds
#     |_embedding -> 0.43948 seconds
#     |_embedding -> 0.410914 seconds
#     |_embedding -> 0.640711 seconds
#     |_embedding -> 0.425726 seconds
#     |_embedding -> 1.055814 seconds
#     |_embedding -> 0.507203 seconds
#     |_embedding -> 0.434446 seconds
#     |_embedding -> 0.449297 seconds
#     |_embedding -> 0.417501 seconds
#     |_embedding -> 0.455061 seconds
#     |_embedding -> 0.424464 seconds
#     |_embedding -> 0.47351 seconds
#     |_embedding -> 0.404617 seconds
#     |_embedding -> 0.407528 seconds
#     |_embedding -> 0.499186 seconds
#     |_embedding -> 0.474878 seconds
#     |_embedding -> 0.428523 seconds
#     |_embedding -> 0.403861 seconds
#     |_embedding -> 0.424941 seconds
#     |_embedding -> 0.430342 seconds
#     |_embedding -> 0.485916 seconds
#     |_embedding -> 0.397755 seconds
#     |_embedding -> 0.431602 seconds
#     |_embedding -> 0.426628 seconds
#     |_embedding -> 0.413752 seconds
#     |_embedding -> 0.563016 seconds
#     |_embedding -> 0.426596 seconds
#     |_embedding -> 0.425967 seconds
#     |_embedding -> 0.432857 seconds
#     |_embedding -> 0.42794 seconds
#     |_embedding -> 0.432289 seconds
#     |_embedding -> 0.406593 seconds
#     |_embedding -> 0.447168 seconds
#     |_embedding -> 0.454457 seconds
#     |_embedding -> 0.419198 seconds
#     |_embedding -> 0.399534 seconds
#     |_embedding -> 0.428129 seconds
#     |_embedding -> 0.463859 seconds
#     |_embedding -> 0.410857 seconds
#     |_embedding -> 0.387906 seconds
#     |_embedding -> 0.408261 seconds
#     |_embedding -> 0.452305 seconds
#     |_embedding -> 1.238884 seconds
#     |_embedding -> 0.67894 seconds
#     |_embedding -> 0.758123 seconds
#     |_embedding -> 0.431339 seconds
#     |_embedding -> 0.425377 seconds
#     |_embedding -> 0.473418 seconds
#     |_embedding -> 0.439762 seconds
#     |_embedding -> 0.437232 seconds
#     |_embedding -> 1.408146 seconds
#     |_embedding -> 0.448869 seconds
#     |_embedding -> 0.436788 seconds
#     |_embedding -> 0.564257 seconds
#     |_embedding -> 0.452258 seconds
#     |_embedding -> 0.440798 seconds
#     |_embedding -> 0.451294 seconds
#     |_embedding -> 1.031018 seconds
#     |_embedding -> 0.447867 seconds
#     |_embedding -> 0.420371 seconds
#     |_embedding -> 0.442143 seconds
#     |_embedding -> 0.433337 seconds
#     |_embedding -> 0.438271 seconds
#     |_embedding -> 0.412297 seconds
#     |_embedding -> 0.471498 seconds
#     |_embedding -> 0.444609 seconds
#     |_embedding -> 0.430246 seconds
#     |_embedding -> 0.43858 seconds
#     |_embedding -> 0.431582 seconds
#     |_embedding -> 0.440049 seconds
#     |_embedding -> 0.460707 seconds
#     |_embedding -> 0.500869 seconds
#     |_embedding -> 0.508978 seconds
#     |_embedding -> 0.452852 seconds
#     |_embedding -> 0.47093 seconds
#     |_embedding -> 0.425738 seconds
#     |_embedding -> 0.429633 seconds
#     |_embedding -> 0.478289 seconds
#     |_embedding -> 0.422466 seconds
#     |_embedding -> 0.56194 seconds
#     |_embedding -> 0.43438 seconds
#     |_embedding -> 0.539252 seconds
#     |_embedding -> 0.460549 seconds
#     |_embedding -> 0.492675 seconds
#     |_embedding -> 1.713921 seconds
#     |_embedding -> 0.444096 seconds
#     |_embedding -> 0.470968 seconds
#     |_embedding -> 0.411195 seconds
#     |_embedding -> 0.447759 seconds
#     |_embedding -> 0.486288 seconds
#     |_embedding -> 0.464366 seconds
#     |_embedding -> 0.414236 seconds
#     |_embedding -> 0.480752 seconds
#     |_embedding -> 0.415017 seconds
#     |_embedding -> 0.403794 seconds
#     |_embedding -> 0.500713 seconds
#     |_embedding -> 0.415889 seconds
#     |_embedding -> 0.317785 seconds
# **********

# %%
docs[0].metadata
# Out:
# {'file_path': '/Users/sam/dev/spaghetti_dev/MedEd-AI/Data/studentguides/350093_130681_Clinic_9_-_Immune_Side_Effects_from_Cancer_Immunotherapy_Consolidation_Assessment_Exercise_Question_3.txt',
#  'file_name': '350093_130681_Clinic_9_-_Immune_Side_Effects_from_Cancer_Immunotherapy_Consolidation_Assessment_Exercise_Question_3.txt',
#  'file_type': 'text/plain',
#  'file_size': 34182,
#  'creation_date': '2024-07-01',
#  'last_modified_date': '2024-07-01',
#  'quiz_id': '350093',
#  'course_id': '130681',
#  'quiz_type': 'graded_survey',
#  'quiz_title': 'Clinic 9 - Immune Side Effects from Cancer Immunotherapy Consolidation Assessment Exercise Question 3'}

# %% [markdown]
# ### Check Metadata

# %%
query = "How many consolidation assessment exercises are there, and what are they called?"
query_engine = vector_index.as_query_engine()
response = query_engine.query(query)
print(response)
# Out:
# **********
# Trace: query
#     |_query -> 3.720691 seconds
#       |_retrieve -> 2.384825 seconds
#         |_embedding -> 0.599231 seconds
#       |_synthesize -> 1.335 seconds
#         |_templating -> 9e-06 seconds
#         |_llm -> 1.326589 seconds
# **********
# There are two consolidation assessment exercises mentioned in the context. One is called "Anatomy 6 Consolidation Assessment Exercise Question 1" and the other is called "Pathology 4 Consolidation Assessment Exercise Question 5".

# %% [markdown]
# ### Define RetrieverQueryEngine

# %%
vector_store_info = VectorStoreInfo(
    content_info="Student guides to help prepare for consolidation assessments",
    metadata_info=[
        MetadataInfo(
            name="page_label",
            description="What page of the file the context is from",
            type="string",
        ),
        MetadataInfo(
            name="file_name",
            description="The name of the file the context is from",
            type="string",
        ),
        MetadataInfo(
            name="file_path",
            description="The file path of the context file",
            type="string",
        ),
        MetadataInfo(
            name="file_type",
            description="The type of file",
            type="string",
        ),
        MetadataInfo(
            name="file_size",
            description="The size of the file in bytes",
            type="integer",
        ),
        MetadataInfo(
            name="creation_date",
            description="When the file was created",
            type="string",
        ),
        MetadataInfo(
            name="last_modified_date",
            description="When the file was last modified",
            type="string",
        ),
        MetadataInfo(
            name="display_name",
            description="The name of the file",
            type="string",
        ),
        MetadataInfo(
            name="week",
            description="The week the context was administered",
            type="string",
        ),
        MetadataInfo(
            name="folder_name",
            description="The course folder that contains the file",
            type="string",
        ),
        MetadataInfo(
            name="course_id",
            description="The unique identifier of the course",
            type="integer",
        ),
        MetadataInfo(
            name="course_name",
            description="The full name of the course",
            type="string",
        ),
        MetadataInfo(
            name="course_code",
            description="The shortened name of the course",
            type="string",
        ),
        MetadataInfo(
            name="course_term",
            description="What term the course was offered in",
            type="string",
        ),
    ],
)

vector_auto_retriever = VectorIndexAutoRetriever(
    vector_index, vector_store_info=vector_store_info
)

retriever_query_engine = RetrieverQueryEngine.from_args(
    vector_auto_retriever, llm=llm
)

# %% [markdown]
# ### Set Up Query Engine Tools

# %%
from llama_index.core.tools import QueryEngineTool

sql_tool = QueryEngineTool.from_defaults(
    query_engine=sql_query_engine,
    description=(
        "Useful for translating a natural language query into a SQL query over"
        " a table svr_course_quiz_view, containing columns:"
        " quiz_id, quiz_type, quiz_title, history_id, submission_id,"
        " student_score, quiz_question_count, quiz_points_possible, question_points_possible," 
        "answer_points_scored, attempt, question_name, question_type, question_text, question_answer, and student_answer"
    ),
)


vector_tool = QueryEngineTool.from_defaults(
        query_engine=retriever_query_engine,
        description=f"Useful for answering semantic questions about consolidation assessments, and general course-related questions like when certain material is being taught",
    )

# %% [markdown]
# ### Define Query Engine

# %%
query_engine = SQLAutoVectorQueryEngine(
    sql_tool, 
    vector_tool,
    llm=llm
)

# %% [markdown]
# ### Query Test 1: Ability to identify topics covered in a specific assessment

# %%
response = query_engine.query("What is in the context?")

response.response
# Out:
# **********
# Trace: query
#     |_query -> 2.643768 seconds
#       |_retrieve -> 0.484422 seconds
#         |_embedding -> 0.287008 seconds
#       |_synthesize -> 2.158525 seconds
#         |_templating -> 9e-06 seconds
#         |_llm -> 2.147489 seconds
# **********
# 'The context information includes details about two different files. The first file is named "334985_130681_Clinic_1_-_Down_Syndrome_Consolidation_Assessment_Exercise__Question_2.txt" and the second file is named "338474_130681_Clinic_2_-_Sickle_Cell_Anemia_Consolidation_Assessment_Exercise__Question_1.txt". The context also provides information about the file type, file size, creation date, last modified date, quiz ID, course ID, quiz type, and quiz title for each file. Additionally, there are student answers provided for each file.'

# %% [markdown]
# ### Query Test 2: Ability to query SQL db, synthesize results and deliver a cohesive answer

# %%
response = query_engine.query("Compare all student answers to the answer for question 1 of CBB 3 Consolidation Assessment Exercise. What concept did students best understand? Which concept was most frequently not mentioned?")

response.response += ' '
out = response.response.split('. ')[:-1]
print('.\n'.join(out))
# Out:
# **********
# Trace: query
#     |_query -> 1.510875 seconds
#       |_retrieve -> 0.459248 seconds
#         |_embedding -> 0.271059 seconds
#       |_synthesize -> 1.050958 seconds
#         |_templating -> 7e-06 seconds
#         |_llm -> 1.043321 seconds
# **********
# Based on the given context information, it is not possible to determine the specific concepts that students best understood or the concept that was most frequently not mentioned in question 1 of the CBB 3 Consolidation Assessment Exercise.
# The context information does not provide any information about the student answers or the specific concepts covered in the exercise

# %% [markdown]
# ### Query Test 3: Ability to identify material from specific time, create quiz questions, create Google quiz

# %%
response = query_engine.query(
    'Identify what material is taught in week 7. Then create a 5 question review quiz on the material taught in week 7. Do not ask questions about text from a photo/graph. Do not ask any questions about textbook sections. Do not ask any questions about learning objectives. Every question should have only one correct answer. Every question should have 4 potential answers. Format the output like this:{"info":{"title": "", "description": "", "questions": [ { "question": "","type": "RADIO","options": [], "correct_answer": ""}]}}'
)

# Google Quiz Creation
form = Form(file_type='credentials', loginfile=CREDENTIALS_FILE,
        discovery_doc=DISCOVERY_DOC, scopes=SCOPES, sentence_response = response)

# %% [markdown]
# ### Chat Session Testing

# %%
# response = query_engine.query(
#     'Identify what material is taught in week 7. Only respond with the topics, separated with commas.'
# )

# response.response

response = query_engine.query(
    'Create a 6 question review quiz on the hormonal Control of Metabolism. Do not ask questions about text from a photo/graph. Do not ask any questions about textbook sections. Do not ask any questions about learning objectives. Every question should have only one correct answer. Every question should have 4 potential answers. 2 of the questions should be easy in difficulty. 2 of the questions should be medium in difficulty. 2 of the questions should be hard in difficulty. Format the output like this:{"info":{"title": "", "description": "", "questions": [ { "question": "","type": "RADIO","options": [], "correct_answer": ""}]}}'
)

# Google Quiz Creation
form = Form(file_type='credentials', loginfile=CREDENTIALS_FILE,
        discovery_doc=DISCOVERY_DOC, scopes=SCOPES, sentence_response = response)
